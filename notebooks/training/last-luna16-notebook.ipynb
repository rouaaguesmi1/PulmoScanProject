# %%
import numpy as np
import pandas as pd
import SimpleITK as sitk # For reading .mhd/.raw files
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob # For finding file paths

# %%
LUNA16_DATA_PATH = '/kaggle/input/luna-16/Dataset'
SUBSET_PATHS = sorted(glob.glob(os.path.join(LUNA16_DATA_PATH, 'subset*/subset*')))
ANNOTATIONS_PATH = os.path.join(LUNA16_DATA_PATH, 'annotations.csv')
CANDIDATES_PATH = os.path.join(LUNA16_DATA_PATH, 'candidates.csv') # If available

print(f"Number of subsets found: {len(SUBSET_PATHS)}")
print(f"Annotations file exists: {os.path.exists(ANNOTATIONS_PATH)}")
if os.path.exists(CANDIDATES_PATH):
    print(f"Candidates file exists: {os.path.exists(CANDIDATES_PATH)}")
else:
     print("Candidates file not found, proceeding with annotations.csv only for confirmed nodules.")
# Out:
# Number of subsets found: 10
# Annotations file exists: True
# Candidates file exists: True

# %%
import pandas as pd

# --- Count Positive Samples ---
print("Counting positive samples (nodules)...")
positive_count = 0

# Iterate through the annotations (df_annos) and count positive samples
if not df_annos.empty:
    positive_count = len(df_annos)
    print(f"Found {positive_count} positive samples (nodules).")
else:
    print("No positive samples found in the annotations.")

# --- Count Negative Samples ---
print("Counting negative samples (non-nodules)...")
negative_count = 0

# Load the candidates.csv file for negative samples
CANDIDATES_PATH = os.path.join(LUNA16_DATA_PATH, 'candidates.csv')

try:
    df_candidates = pd.read_csv(CANDIDATES_PATH)
    # Filter for negative samples (class == 0)
    negative_candidates = df_candidates[df_candidates['class'] == 0]
    negative_count = len(negative_candidates)
    print(f"Found {negative_count} negative samples (non-nodules).")
except Exception as e:
    print(f"Error loading candidates.csv: {e}")

# --- Summary ---
print("\n--- Summary ---")
print(f"Total positive samples: {positive_count}")
print(f"Total negative samples: {negative_count}")
# Out:
# Counting positive samples (nodules)...
# Found 1186 positive samples (nodules).
# Counting negative samples (non-nodules)...
# Found 549714 negative samples (non-nodules).
#
# --- Summary ---
# Total positive samples: 1186
# Total negative samples: 549714

# %%
import pandas as pd

# --- Count Number of Scans for Positive Samples ---
print("Counting number of scans for positive samples (nodules)...")
positive_scans = 0

# Iterate through the annotations (df_annos) and count unique seriesuid values (scans)
if not df_annos.empty:
    positive_scans = df_annos['seriesuid'].nunique()  # Count distinct scans
    print(f"Found {positive_scans} unique scans with positive samples (nodules).")
else:
    print("No positive samples found in the annotations.")

# --- Count Number of Scans for Negative Samples ---
print("Counting number of scans for negative samples (non-nodules)...")
negative_scans = 0

# Load the candidates.csv file for negative samples
CANDIDATES_PATH = os.path.join(LUNA16_DATA_PATH, 'candidates.csv')

try:
    df_candidates = pd.read_csv(CANDIDATES_PATH)
    # Filter for negative samples (class == 0)
    negative_candidates = df_candidates[df_candidates['class'] == 0]
    
    # Count the unique scans (seriesuid) for negative candidates
    negative_scans = negative_candidates['seriesuid'].nunique()
    print(f"Found {negative_scans} unique scans with negative samples (non-nodules).")
except Exception as e:
    print(f"Error loading candidates.csv: {e}")

# --- Summary ---
print("\n--- Summary ---")
print(f"Total unique positive scans: {positive_scans}")
print(f"Total unique negative scans: {negative_scans}")
# Out:
# Counting number of scans for positive samples (nodules)...
# Found 601 unique scans with positive samples (nodules).
# Counting number of scans for negative samples (non-nodules)...
# Found 888 unique scans with negative samples (non-nodules).
#
# --- Summary ---
# Total unique positive scans: 601
# Total unique negative scans: 888

# %%
import os

# --- Count Total Number of Raw Scans (.mhd files) ---
print("Counting total number of raw scans (.mhd files) in subsets...")

# Initialize counters for the total number of scans
total_scans = 0
positive_scan_files = set()  # Set to track raw scans with positive annotations

# Loop through each subset path to count the number of .mhd files
for subset_path in SUBSET_PATHS:
    # List all files in the subset directory
    subset_files = os.listdir(subset_path)
    
    # Count only .mhd files (raw scans)
    mhd_files = [f for f in subset_files if f.endswith('.mhd')]
    total_scans += len(mhd_files)
    
    # Track positive scan files
    for mhd_file in mhd_files:
        seriesuid = mhd_file.split('.')[0]  # Assuming the filename starts with seriesuid
        if seriesuid in df_annos['seriesuid'].values:
            positive_scan_files.add(seriesuid)

# Print the number of raw scans and how many are positive
print(f"Total number of raw scans (.mhd files) across subsets: {total_scans}")
print(f"Total number of raw scans with positive annotations: {len(positive_scan_files)}")

# --- Summary ---
print("\n--- Summary ---")
print(f"Total unique positive scans: {positive_scans}")
print(f"Total unique negative scans: {negative_scans}")
print(f"Total raw scans in subsets: {total_scans}")
print(f"Total positive raw scans in subsets: {len(positive_scan_files)}")
# Out:
# Counting total number of raw scans (.mhd files) in subsets...
# Total number of raw scans (.mhd files) across subsets: 888
# Total number of raw scans with positive annotations: 0
#
# --- Summary ---
# Total unique positive scans: 601
# Total unique negative scans: 888
# Total raw scans in subsets: 888
# Total positive raw scans in subsets: 0

# %%
try:
    df_annos = pd.read_csv(ANNOTATIONS_PATH)
    print("Annotations loaded successfully:")
    print(f"Shape: {df_annos.shape}")
    print(df_annos.head())

    # Check for missing values
    print("\nMissing values in annotations:")
    print(df_annos.isnull().sum())

except FileNotFoundError:
    print(f"Error: Annotations file not found at {ANNOTATIONS_PATH}")
    df_annos = pd.DataFrame() # Create empty dataframe if file not found
# Out:
# Annotations loaded successfully:
# Shape: (1186, 5)
#                                            seriesuid      coordX      coordY  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017 -140.944586
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824  192.102405
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547  172.464881
#
#        coordZ  diameter_mm
# 0 -298.387506     5.651471
# 1 -227.121250     4.224708
# 2  876.374496     5.786348
# 3 -391.081276     8.143262
# 4 -405.493732    18.545150
#
# Missing values in annotations:
# seriesuid      0
# coordX         0
# coordY         0
# coordZ         0
# diameter_mm    0
# dtype: int64

# %%
df_cands = None
if os.path.exists(CANDIDATES_PATH):
    try:
        df_cands = pd.read_csv(CANDIDATES_PATH)
        print("\nCandidates loaded successfully:")
        print(f"Shape: {df_cands.shape}")
        print(df_cands.head())
        print("\nMissing values in candidates:")
        print(df_cands.isnull().sum())
    except FileNotFoundError:
        print(f"Warning: Candidates file specified but not found at {CANDIDATES_PATH}")
# Out:
# Candidates loaded successfully:
# Shape: (551065, 5)
#                                            seriesuid  coordX  coordY  coordZ  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -56.08  -67.85 -311.92
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   53.21 -244.41 -245.17
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.66 -121.80 -286.62
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -33.66  -72.75 -308.41
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -32.25  -85.36 -362.51
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#
# Missing values in candidates:
# seriesuid    0
# coordX       0
# coordY       0
# coordZ       0
# class        0
# dtype: int64

# %%
if not df_annos.empty:
    print("\nAnnotation Statistics:")
    print(df_annos.describe())

    # Plot distribution of nodule diameters
    plt.figure(figsize=(10, 5))
    sns.histplot(df_annos['diameter_mm'], bins=30, kde=True)
    plt.title('Distribution of Nodule Diameters (mm)')
    plt.xlabel('Diameter (mm)')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    # Count nodules per scan
    nodules_per_scan = df_annos['seriesuid'].value_counts()
    print(f"\nScans with nodules: {len(nodules_per_scan)}")
    print(f"Average nodules per scan (for scans with nodules): {nodules_per_scan.mean():.2f}")

    plt.figure(figsize=(10, 5))
    sns.histplot(nodules_per_scan, bins=max(nodules_per_scan), discrete=True)
    plt.title('Distribution of Number of Nodules per Scan')
    plt.xlabel('Number of Nodules')
    plt.ylabel('Number of Scans')
    plt.grid(True)
    plt.show()
# Out:
# Annotation Statistics:
#             coordX       coordY       coordZ  diameter_mm
# count  1186.000000  1186.000000  1186.000000  1186.000000
# mean     -5.067547     8.428113  -160.159029     8.306527
# std      84.468115    98.316003   279.829437     4.762033
# min    -164.351031  -283.834336  -790.074799     3.253443
# 25%     -80.909225   -51.549643  -221.197808     5.107177
# 50%     -32.855132    18.787926  -167.615160     6.433600
# 75%      76.830069    67.245915  -109.735281     9.696301
# max     164.763985   271.405521  1790.494057    32.270030
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Scans with nodules: 601
# Average nodules per scan (for scans with nodules): 1.97
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
def load_itk_image(filename):
    """Loads a .mhd file using SimpleITK and returns the image array and metadata."""
    try:
        itkimage = sitk.ReadImage(filename)
        # Convert to numpy array (depth, height, width)
        image_array = sitk.GetArrayFromImage(itkimage)

        # Metadata: Origin (world coords of first voxel), Spacing (size of voxel), Direction (orientation)
        origin = np.array(itkimage.GetOrigin())
        spacing = np.array(itkimage.GetSpacing())
        direction = np.array(itkimage.GetDirection()).reshape(3, 3)

        return image_array, origin, spacing, direction  # <-- This was missing!

    except Exception as e:
        print(f"Error loading {filename}: {e}")
        return None  # Explicitly return None if an error occurs

# %%
def world_to_voxel(world_coords, origin, spacing, direction):
    """Converts world coordinates (x, y, z) to voxel coordinates (col, row, slice)."""

    # Ensure world_coords is a NumPy array
    world_coords = np.array(world_coords, dtype=np.float64)  
    if world_coords.shape != (3,):
        raise ValueError(f"Unexpected world coordinate shape: {world_coords.shape}, expected (3,)")

    # Check if Direction is identity or close to it
    is_identity_like = np.allclose(direction, np.identity(3)) or np.allclose(direction, np.diag([-1, -1, 1])) 

    if is_identity_like:
        voxel_coords = (world_coords - origin) / spacing
        return np.round(voxel_coords[[2, 1, 0]]).astype(int)
    else:
        print("Warning: Non-standard direction matrix encountered. Voxel conversion might need adjustment.")
        relative_coords = world_coords - origin
        voxel_coords_temp = np.linalg.inv(direction @ np.diag(spacing)) @ relative_coords
        return np.round(voxel_coords_temp[[2, 1, 0]]).astype(int)

# %%
def plot_slice_with_nodule(image_array, voxel_coords, diameter_mm, spacing):
    """Plots a 2D slice of the CT scan containing the nodule center."""
    slice_idx, row_idx, col_idx = voxel_coords

    # Ensure indices are within bounds
    slice_idx = np.clip(slice_idx, 0, image_array.shape[0] - 1)
    row_idx = np.clip(row_idx, 0, image_array.shape[1] - 1)
    col_idx = np.clip(col_idx, 0, image_array.shape[2] - 1)

    # Get the 2D slice (it's a Y-Z plane if we index with col_idx, X-Z if row_idx, X-Y if slice_idx)
    # Let's plot the axial slice (X-Y plane) at the nodule's Z coordinate
    axial_slice = image_array[slice_idx, :, :]

    plt.figure(figsize=(8, 8))
    plt.imshow(axial_slice, cmap=plt.cm.gray)
    plt.title(f'Axial Slice (Z={slice_idx}) with Nodule Center')
    plt.xlabel('X (col)')
    plt.ylabel('Y (row)')

    # Calculate radius in pixels (approximate, use average spacing for simplicity)
    # Use spacing corresponding to the slice axes (x, y) -> spacing[0], spacing[1]
    radius_pixels_x = (diameter_mm / 2.0) / spacing[0]
    radius_pixels_y = (diameter_mm / 2.0) / spacing[1]
    # Average radius for circular marker
    avg_radius_pixels = (radius_pixels_x + radius_pixels_y) / 2.0

    # Draw a circle marker at the nodule center (col_idx, row_idx)
    # Note: plt.scatter uses (x, y) coordinates, corresponding to (col, row) indices
    circle = plt.Circle((col_idx, row_idx), avg_radius_pixels, color='r', fill=False, linewidth=2)
    plt.gca().add_patch(circle)
    plt.scatter(col_idx, row_idx, color='r', marker='+', s=100) # Mark center
    plt.show()

# %%
if not df_annos.empty:
    # Get the first annotation
    sample_annotation = df_annos.iloc[0]
    seriesuid = sample_annotation['seriesuid']
    world_coords = sample_annotation[['coordX', 'coordY', 'coordZ']].values
    diameter = sample_annotation['diameter_mm']

    print(f"Visualizing nodule from scan: {seriesuid}")
    print(f"World Coordinates (x,y,z): {world_coords}")
    print(f"Diameter: {diameter} mm")

    # Find the corresponding .mhd file
    mhd_file = None
    for subset_path in SUBSET_PATHS:
        potential_file = os.path.join(subset_path, f"{seriesuid}.mhd")
        if os.path.exists(potential_file):
            mhd_file = potential_file
            break

    if mhd_file:
        print(f"Loading image file: {mhd_file}")
        image_array, origin, spacing, direction = load_itk_image(mhd_file)
        print(f"Image shape (D, H, W): {image_array.shape}")
        print(f"Origin: {origin}")
        print(f"Spacing: {spacing}")
        # print(f"Direction Matrix:\n{direction}") # Optional: print direction matrix

        # Convert world coordinates to voxel coordinates
        voxel_coords = world_to_voxel(world_coords, origin, spacing, direction)
        print(f"Voxel Coordinates (slice, row, col): {voxel_coords}")

        # Plot the relevant slice
        plot_slice_with_nodule(image_array, voxel_coords, diameter, spacing)
    else:
        print(f"Error: Could not find .mhd file for seriesuid {seriesuid}")
else:
    print("No annotations loaded, skipping visualization example.")
# Out:
# Visualizing nodule from scan: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# World Coordinates (x,y,z): [-128.6994211 -175.3192718 -298.3875064]
# Diameter: 5.651470635 mm
# Loading image file: /kaggle/input/luna-16/Dataset/subset8/subset8/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd
# Image shape (D, H, W): (194, 512, 512)
# Origin: [-157.67773 -311.67773 -438.4    ]
# Spacing: [0.64453125 0.64453125 1.79999995]
# Voxel Coordinates (slice, row, col): [ 78 212  45]

# %%
from scipy.ndimage import zoom

def resample_image(image_array, spacing, new_spacing=[1, 1, 1]):
    """Resamples the image to a new spacing."""
    resize_factor = spacing / new_spacing
    new_real_shape = image_array.shape * resize_factor
    new_shape = np.round(new_real_shape)
    real_resize_factor = new_shape / image_array.shape
    new_spacing = spacing / real_resize_factor

    # Use spline interpolation (order=1 for linear, order=3 for cubic)
    resampled_image = zoom(image_array, real_resize_factor, order=1)

    return resampled_image, new_spacing

# %%
# Example: Resample the previously loaded image
if 'image_array' in locals():
    print(f"Original shape: {image_array.shape}, Original spacing: {spacing}")
    
    # Resampling
    resampled_img, new_spacing_actual = resample_image(image_array, spacing, new_spacing=[1, 1, 1])
    
    print(f"Resampled shape: {resampled_img.shape}, New spacing: {new_spacing_actual}")
    
    # Visualization
    def visualize_resampled(image, title="Resampled Image"):
        mid_slice = image.shape[0] // 2  # Choose the middle slice
        plt.imshow(image[mid_slice, :, :], cmap='gray')
        plt.title(title)
        plt.axis('off')
        plt.show()
    
    visualize_resampled(resampled_img)

else:
    print("Skipping resampling example as no image was loaded.")
# Out:
# Original shape: (194, 512, 512), Original spacing: [0.64453125 0.64453125 1.79999995]
# Resampled shape: (125, 330, 922), New spacing: [1.0003125  1.         0.99956613]

# %%
def normalize_hu(image_array):
    """Normalizes HU values."""
    # Typical range for lung tissue/nodules
    MIN_BOUND = -1000.0
    MAX_BOUND = 400.0
    image_array = np.clip(image_array, MIN_BOUND, MAX_BOUND)

    # Normalize to [0, 1]
    image_array = (image_array - MIN_BOUND) / (MAX_BOUND - MIN_BOUND)
    return image_array.astype(np.float32)

# %%
def visualize_image(image, title="Image Slice"):
    """Displays the middle slice of a 3D image."""
    mid_slice = image.shape[0] // 2  # Choose the middle slice
    plt.figure(figsize=(6,6))
    plt.imshow(image[mid_slice, :, :], cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# Example usage
if 'image_array' in locals():
    print(f"Original shape: {image_array.shape}, Original spacing: {spacing}")

    # Step 1: Resample
    resampled_img, new_spacing_actual = resample_image(image_array, spacing, new_spacing=[1, 1, 1])
    print(f"Resampled shape: {resampled_img.shape}, New spacing: {new_spacing_actual}")

    # Step 2: Normalize HU values
    normalized_img = normalize_hu(resampled_img)
    print(f"Normalized image min/max: {normalized_img.min()}, {normalized_img.max()}")

    # Step 3: Visualize
    visualize_image(normalized_img, title="Normalized Resampled Image Slice")

else:
    print("Skipping processing as no image was loaded.")
# Out:
# Original shape: (194, 512, 512), Original spacing: [0.64453125 0.64453125 1.79999995]
# Resampled shape: (125, 330, 922), New spacing: [1.0003125  1.         0.99956613]
# Normalized image min/max: 0.0, 1.0

# %%
def simple_lung_segmentation(image_array):
    """Very basic lung segmentation using thresholding."""
    # Assumes input image is already normalized (values between 0 and 1)
    # Thresholding air (-1000 HU maps to 0) and dense tissue (400 HU maps to 1)
    # Lungs are mostly air, so we look for low intensity values after normalization
    segmented = np.where(image_array > 0.25, 1.0, 0.0)  # Crude threshold

    print("Warning: Using very basic lung segmentation.")
    return segmented * image_array  # Mask the original image

# %%
# Example usage
if 'normalized_img' in locals():
    # Step 1: Perform segmentation
    segmented_img = simple_lung_segmentation(normalized_img)
    
    # Step 2: Visualize the segmented lungs
    visualize_image(segmented_img, title="Segmented Lung Image (Basic Thresholding)")

else:
    print("Skipping segmentation example.")
# Out:
# Warning: Using very basic lung segmentation.

# %%
def extract_patch(image_array, voxel_coords, patch_size=(64, 64, 64)):
    """Extracts a 3D patch centered at voxel_coords."""
    patch_z, patch_y, patch_x = patch_size
    cz, cy, cx = voxel_coords

    # Calculate start and end indices for slicing, handling boundaries
    start_z = max(0, cz - patch_z // 2)
    end_z = min(image_array.shape[0], cz + (patch_z + 1) // 2)
    start_y = max(0, cy - patch_y // 2)
    end_y = min(image_array.shape[1], cy + (patch_y + 1) // 2)
    start_x = max(0, cx - patch_x // 2)
    end_x = min(image_array.shape[2], cx + (patch_x + 1) // 2)

    patch = image_array[start_z:end_z, start_y:end_y, start_x:end_x]

    # Pad if the patch is smaller than desired size (due to boundary proximity)
    pad_z = patch_size[0] - patch.shape[0]
    pad_y = patch_size[1] - patch.shape[1]
    pad_x = patch_size[2] - patch.shape[2]

    pad_width = ((pad_z // 2, (pad_z + 1) // 2), # Before/After padding for Z
                 (pad_y // 2, (pad_y + 1) // 2), # Before/After padding for Y
                 (pad_x // 2, (pad_x + 1) // 2)) # Before/After padding for X

    # Use a constant padding value, e.g., the minimum value of the image or 0 if normalized
    pad_value = np.min(image_array) # Or 0 if normalized [0,1]
    patch = np.pad(patch, pad_width, mode='constant', constant_values=pad_value)

    return patch

# %%
PATCH_SIZE = (48, 48, 48) # Example patch size (z, y, x)
TARGET_SPACING = np.array([1.0, 1.0, 1.0]) # Target isotropic spacing in mm

positive_patches = []
negative_patches = []
labels = [] # 1 for nodule, 0 for non-nodule

# --- Process Positive Samples (from annotations.csv) ---
print("Processing positive samples (nodules)...")
processed_scans = 0
total_scans = len(df_annos)  # Total number of scans to process

if not df_annos.empty:
    for idx, row in df_annos.iterrows():
        seriesuid = row['seriesuid']
        world_coords = row[['coordX', 'coordY', 'coordZ']].values
        diameter = row['diameter_mm']

        # Find and load the image
        mhd_file = None
        for subset_path in SUBSET_PATHS:
            potential_file = os.path.join(subset_path, f"{seriesuid}.mhd")
            if os.path.exists(potential_file):
                mhd_file = potential_file
                break

        if not mhd_file: continue  # Skip if file not found

        try:
            image_array, origin, spacing, direction = load_itk_image(mhd_file)

            # Preprocess: Resample -> Normalize -> (Segment)
            resampled_img, new_spacing = resample_image(image_array, spacing, TARGET_SPACING)
            normalized_img = normalize_hu(resampled_img)
            # segmented_img = simple_lung_segmentation(normalized_img) # Optional

            # Adjust coordinates for resampling
            original_voxel_coords = world_to_voxel(world_coords, origin, spacing, direction)
            new_voxel_coords = world_to_voxel(world_coords, origin, new_spacing, direction)

            # Extract patch around the *new* voxel coordinates
            patch = extract_patch(normalized_img, new_voxel_coords, patch_size=PATCH_SIZE)
            positive_patches.append(patch)
            labels.append(1)
            processed_scans += 1

            # Print progress after each scan
            print(f"Processed {processed_scans}/{total_scans} scans...")

        except Exception as e:
            print(f"Error processing {seriesuid}: {e}")

    print(f"Processed {len(positive_patches)} positive patches from {processed_scans} scans.")
# Out:
# Processing positive samples (nodules)...
# Processed 1/1186 scans...
# Processed 2/1186 scans...
# Processed 3/1186 scans...
# Processed 4/1186 scans...
# Processed 5/1186 scans...
# Processed 6/1186 scans...
# Processed 7/1186 scans...
# Processed 8/1186 scans...
# Processed 9/1186 scans...
# Processed 10/1186 scans...
# Processed 11/1186 scans...
# Processed 12/1186 scans...
# Processed 13/1186 scans...
# Processed 14/1186 scans...
# Processed 15/1186 scans...
# Processed 16/1186 scans...
# Processed 17/1186 scans...
# Processed 18/1186 scans...
# Processed 19/1186 scans...
# Processed 20/1186 scans...
# Processed 21/1186 scans...
# Processed 22/1186 scans...
# Processed 23/1186 scans...
# Processed 24/1186 scans...
# Processed 25/1186 scans...
# Processed 26/1186 scans...
# Processed 27/1186 scans...
# Processed 28/1186 scans...
# Processed 29/1186 scans...
# Processed 30/1186 scans...
# Processed 31/1186 scans...
# Processed 32/1186 scans...
# Processed 33/1186 scans...
# Processed 34/1186 scans...
# Processed 35/1186 scans...
# Processed 36/1186 scans...
# Processed 37/1186 scans...
# Processed 38/1186 scans...
# Processed 39/1186 scans...
# Processed 40/1186 scans...
# Processed 41/1186 scans...
# Processed 42/1186 scans...
# Processed 43/1186 scans...
# Processed 44/1186 scans...
# Processed 45/1186 scans...
# Processed 46/1186 scans...
# Processed 47/1186 scans...
# Processed 48/1186 scans...
# Processed 49/1186 scans...
# Processed 50/1186 scans...
# Processed 51/1186 scans...
# Processed 52/1186 scans...
# Processed 53/1186 scans...
# Processed 54/1186 scans...
# Processed 55/1186 scans...
# Processed 56/1186 scans...
# Processed 57/1186 scans...
# Processed 58/1186 scans...
# Processed 59/1186 scans...
# Processed 60/1186 scans...
# Processed 61/1186 scans...
# Processed 62/1186 scans...
# Processed 63/1186 scans...
# Processed 64/1186 scans...
# Processed 65/1186 scans...
# Processed 66/1186 scans...
# Processed 67/1186 scans...
# Processed 68/1186 scans...
# Processed 69/1186 scans...
# Processed 70/1186 scans...
# Processed 71/1186 scans...
# Processed 72/1186 scans...
# Processed 73/1186 scans...
# Processed 74/1186 scans...
# Processed 75/1186 scans...
# Processed 76/1186 scans...
# Processed 77/1186 scans...
# Processed 78/1186 scans...
# Processed 79/1186 scans...
# Processed 80/1186 scans...
# Processed 81/1186 scans...
# Processed 82/1186 scans...
# Processed 83/1186 scans...
# Processed 84/1186 scans...
# Processed 85/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.123697637451437522065941162930: index can't contain negative values
# Processed 86/1186 scans...
# Processed 87/1186 scans...
# Processed 88/1186 scans...
# Processed 89/1186 scans...
# Processed 90/1186 scans...
# Processed 91/1186 scans...
# Processed 92/1186 scans...
# Processed 93/1186 scans...
# Processed 94/1186 scans...
# Processed 95/1186 scans...
# Processed 96/1186 scans...
# Processed 97/1186 scans...
# Processed 98/1186 scans...
# Processed 99/1186 scans...
# Processed 100/1186 scans...
# Processed 101/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.127965161564033605177803085629: index can't contain negative values
# Processed 102/1186 scans...
# Processed 103/1186 scans...
# Processed 104/1186 scans...
# Processed 105/1186 scans...
# Processed 106/1186 scans...
# Processed 107/1186 scans...
# Processed 108/1186 scans...
# Processed 109/1186 scans...
# Processed 110/1186 scans...
# Processed 111/1186 scans...
# Processed 112/1186 scans...
# Processed 113/1186 scans...
# Processed 114/1186 scans...
# Processed 115/1186 scans...
# Processed 116/1186 scans...
# Processed 117/1186 scans...
# Processed 118/1186 scans...
# Processed 119/1186 scans...
# Processed 120/1186 scans...
# Processed 121/1186 scans...
# Processed 122/1186 scans...
# Processed 123/1186 scans...
# Processed 124/1186 scans...
# Processed 125/1186 scans...
# Processed 126/1186 scans...
# Processed 127/1186 scans...
# Processed 128/1186 scans...
# Processed 129/1186 scans...
# Processed 130/1186 scans...
# Processed 131/1186 scans...
# Processed 132/1186 scans...
# Processed 133/1186 scans...
# Processed 134/1186 scans...
# Processed 135/1186 scans...
# Processed 136/1186 scans...
# Processed 137/1186 scans...
# Processed 138/1186 scans...
# Processed 139/1186 scans...
# Processed 140/1186 scans...
# Processed 141/1186 scans...
# Processed 142/1186 scans...
# Processed 143/1186 scans...
# Processed 144/1186 scans...
# Processed 145/1186 scans...
# Processed 146/1186 scans...
# Processed 147/1186 scans...
# Processed 148/1186 scans...
# Processed 149/1186 scans...
# Processed 150/1186 scans...
# Processed 151/1186 scans...
# Processed 152/1186 scans...
# Processed 153/1186 scans...
# Processed 154/1186 scans...
# Processed 155/1186 scans...
# Processed 156/1186 scans...
# Processed 157/1186 scans...
# Processed 158/1186 scans...
# Processed 159/1186 scans...
# Processed 160/1186 scans...
# Processed 161/1186 scans...
# Processed 162/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.144883090372691745980459537053: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.144883090372691745980459537053: index can't contain negative values
# Processed 163/1186 scans...
# Processed 164/1186 scans...
# Processed 165/1186 scans...
# Processed 166/1186 scans...
# Processed 167/1186 scans...
# Processed 168/1186 scans...
# Processed 169/1186 scans...
# Processed 170/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689: index can't contain negative values
# Processed 171/1186 scans...
# Processed 172/1186 scans...
# Processed 173/1186 scans...
# Processed 174/1186 scans...
# Processed 175/1186 scans...
# Processed 176/1186 scans...
# Processed 177/1186 scans...
# Processed 178/1186 scans...
# Processed 179/1186 scans...
# Processed 180/1186 scans...
# Processed 181/1186 scans...
# Processed 182/1186 scans...
# Processed 183/1186 scans...
# Processed 184/1186 scans...
# Processed 185/1186 scans...
# Processed 186/1186 scans...
# Processed 187/1186 scans...
# Processed 188/1186 scans...
# Processed 189/1186 scans...
# Processed 190/1186 scans...
# Processed 191/1186 scans...
# Processed 192/1186 scans...
# Processed 193/1186 scans...
# Processed 194/1186 scans...
# Processed 195/1186 scans...
# Processed 196/1186 scans...
# Processed 197/1186 scans...
# Processed 198/1186 scans...
# Processed 199/1186 scans...
# Processed 200/1186 scans...
# Processed 201/1186 scans...
# Processed 202/1186 scans...
# Processed 203/1186 scans...
# Processed 204/1186 scans...
# Processed 205/1186 scans...
# Processed 206/1186 scans...
# Processed 207/1186 scans...
# Processed 208/1186 scans...
# Processed 209/1186 scans...
# Processed 210/1186 scans...
# Processed 211/1186 scans...
# Processed 212/1186 scans...
# Processed 213/1186 scans...
# Processed 214/1186 scans...
# Processed 215/1186 scans...
# Processed 216/1186 scans...
# Processed 217/1186 scans...
# Processed 218/1186 scans...
# Processed 219/1186 scans...
# Processed 220/1186 scans...
# Processed 221/1186 scans...
# Processed 222/1186 scans...
# Processed 223/1186 scans...
# Processed 224/1186 scans...
# Processed 225/1186 scans...
# Processed 226/1186 scans...
# Processed 227/1186 scans...
# Processed 228/1186 scans...
# Processed 229/1186 scans...
# Processed 230/1186 scans...
# Processed 231/1186 scans...
# Processed 232/1186 scans...
# Processed 233/1186 scans...
# Processed 234/1186 scans...
# Processed 235/1186 scans...
# Processed 236/1186 scans...
# Processed 237/1186 scans...
# Processed 238/1186 scans...
# Processed 239/1186 scans...
# Processed 240/1186 scans...
# Processed 241/1186 scans...
# Processed 242/1186 scans...
# Processed 243/1186 scans...
# Processed 244/1186 scans...
# Processed 245/1186 scans...
# Processed 246/1186 scans...
# Processed 247/1186 scans...
# Processed 248/1186 scans...
# Processed 249/1186 scans...
# Processed 250/1186 scans...
# Processed 251/1186 scans...
# Processed 252/1186 scans...
# Processed 253/1186 scans...
# Processed 254/1186 scans...
# Processed 255/1186 scans...
# Processed 256/1186 scans...
# Processed 257/1186 scans...
# Processed 258/1186 scans...
# Processed 259/1186 scans...
# Processed 260/1186 scans...
# Processed 261/1186 scans...
# Processed 262/1186 scans...
# Processed 263/1186 scans...
# Processed 264/1186 scans...
# Processed 265/1186 scans...
# Processed 266/1186 scans...
# Processed 267/1186 scans...
# Processed 268/1186 scans...
# Processed 269/1186 scans...
# Processed 270/1186 scans...
# Processed 271/1186 scans...
# Processed 272/1186 scans...
# Processed 273/1186 scans...
# Processed 274/1186 scans...
# Processed 275/1186 scans...
# Processed 276/1186 scans...
# Processed 277/1186 scans...
# Processed 278/1186 scans...
# Processed 279/1186 scans...
# Processed 280/1186 scans...
# Processed 281/1186 scans...
# Processed 282/1186 scans...
# Processed 283/1186 scans...
# Processed 284/1186 scans...
# Processed 285/1186 scans...
# Processed 286/1186 scans...
# Processed 287/1186 scans...
# Processed 288/1186 scans...
# Processed 289/1186 scans...
# Processed 290/1186 scans...
# Processed 291/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.177252583002664900748714851615: index can't contain negative values
# Processed 292/1186 scans...
# Processed 293/1186 scans...
# Processed 294/1186 scans...
# Processed 295/1186 scans...
# Processed 296/1186 scans...
# Processed 297/1186 scans...
# Processed 298/1186 scans...
# Processed 299/1186 scans...
# Processed 300/1186 scans...
# Processed 301/1186 scans...
# Processed 302/1186 scans...
# Processed 303/1186 scans...
# Processed 304/1186 scans...
# Processed 305/1186 scans...
# Processed 306/1186 scans...
# Processed 307/1186 scans...
# Processed 308/1186 scans...
# Processed 309/1186 scans...
# Processed 310/1186 scans...
# Processed 311/1186 scans...
# Processed 312/1186 scans...
# Processed 313/1186 scans...
# Processed 314/1186 scans...
# Processed 315/1186 scans...
# Processed 316/1186 scans...
# Processed 317/1186 scans...
# Processed 318/1186 scans...
# Processed 319/1186 scans...
# Processed 320/1186 scans...
# Processed 321/1186 scans...
# Processed 322/1186 scans...
# Processed 323/1186 scans...
# Processed 324/1186 scans...
# Processed 325/1186 scans...
# Processed 326/1186 scans...
# Processed 327/1186 scans...
# Processed 328/1186 scans...
# Processed 329/1186 scans...
# Processed 330/1186 scans...
# Processed 331/1186 scans...
# Processed 332/1186 scans...
# Processed 333/1186 scans...
# Processed 334/1186 scans...
# Processed 335/1186 scans...
# Processed 336/1186 scans...
# Processed 337/1186 scans...
# Processed 338/1186 scans...
# Processed 339/1186 scans...
# Processed 340/1186 scans...
# Processed 341/1186 scans...
# Processed 342/1186 scans...
# Processed 343/1186 scans...
# Processed 344/1186 scans...
# Processed 345/1186 scans...
# Processed 346/1186 scans...
# Processed 347/1186 scans...
# Processed 348/1186 scans...
# Processed 349/1186 scans...
# Processed 350/1186 scans...
# Processed 351/1186 scans...
# Processed 352/1186 scans...
# Processed 353/1186 scans...
# Processed 354/1186 scans...
# Processed 355/1186 scans...
# Processed 356/1186 scans...
# Processed 357/1186 scans...
# Processed 358/1186 scans...
# Processed 359/1186 scans...
# Processed 360/1186 scans...
# Processed 361/1186 scans...
# Processed 362/1186 scans...
# Processed 363/1186 scans...
# Processed 364/1186 scans...
# Processed 365/1186 scans...
# Processed 366/1186 scans...
# Processed 367/1186 scans...
# Processed 368/1186 scans...
# Processed 369/1186 scans...
# Processed 370/1186 scans...
# Processed 371/1186 scans...
# Processed 372/1186 scans...
# Processed 373/1186 scans...
# Processed 374/1186 scans...
# Processed 375/1186 scans...
# Processed 376/1186 scans...
# Processed 377/1186 scans...
# Processed 378/1186 scans...
# Processed 379/1186 scans...
# Processed 380/1186 scans...
# Processed 381/1186 scans...
# Processed 382/1186 scans...
# Processed 383/1186 scans...
# Processed 384/1186 scans...
# Processed 385/1186 scans...
# Processed 386/1186 scans...
# Processed 387/1186 scans...
# Processed 388/1186 scans...
# Processed 389/1186 scans...
# Processed 390/1186 scans...
# Processed 391/1186 scans...
# Processed 392/1186 scans...
# Processed 393/1186 scans...
# Processed 394/1186 scans...
# Processed 395/1186 scans...
# Processed 396/1186 scans...
# Processed 397/1186 scans...
# Processed 398/1186 scans...
# Processed 399/1186 scans...
# Processed 400/1186 scans...
# Processed 401/1186 scans...
# Processed 402/1186 scans...
# Processed 403/1186 scans...
# Processed 404/1186 scans...
# Processed 405/1186 scans...
# Processed 406/1186 scans...
# Processed 407/1186 scans...
# Processed 408/1186 scans...
# Processed 409/1186 scans...
# Processed 410/1186 scans...
# Processed 411/1186 scans...
# Processed 412/1186 scans...
# Processed 413/1186 scans...
# Processed 414/1186 scans...
# Processed 415/1186 scans...
# Processed 416/1186 scans...
# Processed 417/1186 scans...
# Processed 418/1186 scans...
# Processed 419/1186 scans...
# Processed 420/1186 scans...
# Processed 421/1186 scans...
# Processed 422/1186 scans...
# Processed 423/1186 scans...
# Processed 424/1186 scans...
# Processed 425/1186 scans...
# Processed 426/1186 scans...
# Processed 427/1186 scans...
# Processed 428/1186 scans...
# Processed 429/1186 scans...
# Processed 430/1186 scans...
# Processed 431/1186 scans...
# Processed 432/1186 scans...
# Processed 433/1186 scans...
# Processed 434/1186 scans...
# Processed 435/1186 scans...
# Processed 436/1186 scans...
# Processed 437/1186 scans...
# Processed 438/1186 scans...
# Processed 439/1186 scans...
# Processed 440/1186 scans...
# Processed 441/1186 scans...
# Processed 442/1186 scans...
# Processed 443/1186 scans...
# Processed 444/1186 scans...
# Processed 445/1186 scans...
# Processed 446/1186 scans...
# Processed 447/1186 scans...
# Processed 448/1186 scans...
# Processed 449/1186 scans...
# Processed 450/1186 scans...
# Processed 451/1186 scans...
# Processed 452/1186 scans...
# Processed 453/1186 scans...
# Processed 454/1186 scans...
# Processed 455/1186 scans...
# Processed 456/1186 scans...
# Processed 457/1186 scans...
# Processed 458/1186 scans...
# Processed 459/1186 scans...
# Processed 460/1186 scans...
# Processed 461/1186 scans...
# Processed 462/1186 scans...
# Processed 463/1186 scans...
# Processed 464/1186 scans...
# Processed 465/1186 scans...
# Processed 466/1186 scans...
# Processed 467/1186 scans...
# Processed 468/1186 scans...
# Processed 469/1186 scans...
# Processed 470/1186 scans...
# Processed 471/1186 scans...
# Processed 472/1186 scans...
# Processed 473/1186 scans...
# Processed 474/1186 scans...
# Processed 475/1186 scans...
# Processed 476/1186 scans...
# Processed 477/1186 scans...
# Processed 478/1186 scans...
# Processed 479/1186 scans...
# Processed 480/1186 scans...
# Processed 481/1186 scans...
# Processed 482/1186 scans...
# Processed 483/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.219349715895470349269596532320: index can't contain negative values
# Processed 484/1186 scans...
# Processed 485/1186 scans...
# Processed 486/1186 scans...
# Processed 487/1186 scans...
# Processed 488/1186 scans...
# Processed 489/1186 scans...
# Processed 490/1186 scans...
# Processed 491/1186 scans...
# Processed 492/1186 scans...
# Processed 493/1186 scans...
# Processed 494/1186 scans...
# Processed 495/1186 scans...
# Processed 496/1186 scans...
# Processed 497/1186 scans...
# Processed 498/1186 scans...
# Processed 499/1186 scans...
# Processed 500/1186 scans...
# Processed 501/1186 scans...
# Processed 502/1186 scans...
# Processed 503/1186 scans...
# Processed 504/1186 scans...
# Processed 505/1186 scans...
# Processed 506/1186 scans...
# Processed 507/1186 scans...
# Processed 508/1186 scans...
# Processed 509/1186 scans...
# Processed 510/1186 scans...
# Processed 511/1186 scans...
# Processed 512/1186 scans...
# Processed 513/1186 scans...
# Processed 514/1186 scans...
# Processed 515/1186 scans...
# Processed 516/1186 scans...
# Processed 517/1186 scans...
# Processed 518/1186 scans...
# Processed 519/1186 scans...
# Processed 520/1186 scans...
# Processed 521/1186 scans...
# Processed 522/1186 scans...
# Processed 523/1186 scans...
# Processed 524/1186 scans...
# Processed 525/1186 scans...
# Processed 526/1186 scans...
# Processed 527/1186 scans...
# Processed 528/1186 scans...
# Processed 529/1186 scans...
# Processed 530/1186 scans...
# Processed 531/1186 scans...
# Processed 532/1186 scans...
# Processed 533/1186 scans...
# Processed 534/1186 scans...
# Processed 535/1186 scans...
# Processed 536/1186 scans...
# Processed 537/1186 scans...
# Processed 538/1186 scans...
# Processed 539/1186 scans...
# Processed 540/1186 scans...
# Processed 541/1186 scans...
# Processed 542/1186 scans...
# Processed 543/1186 scans...
# Processed 544/1186 scans...
# Processed 545/1186 scans...
# Processed 546/1186 scans...
# Processed 547/1186 scans...
# Processed 548/1186 scans...
# Processed 549/1186 scans...
# Processed 550/1186 scans...
# Processed 551/1186 scans...
# Processed 552/1186 scans...
# Processed 553/1186 scans...
# Processed 554/1186 scans...
# Processed 555/1186 scans...
# Processed 556/1186 scans...
# Processed 557/1186 scans...
# Processed 558/1186 scans...
# Processed 559/1186 scans...
# Processed 560/1186 scans...
# Processed 561/1186 scans...
# Processed 562/1186 scans...
# Processed 563/1186 scans...
# Processed 564/1186 scans...
# Processed 565/1186 scans...
# Processed 566/1186 scans...
# Processed 567/1186 scans...
# Processed 568/1186 scans...
# Processed 569/1186 scans...
# Processed 570/1186 scans...
# Processed 571/1186 scans...
# Processed 572/1186 scans...
# Processed 573/1186 scans...
# Processed 574/1186 scans...
# Processed 575/1186 scans...
# Processed 576/1186 scans...
# Processed 577/1186 scans...
# Processed 578/1186 scans...
# Processed 579/1186 scans...
# Processed 580/1186 scans...
# Processed 581/1186 scans...
# Processed 582/1186 scans...
# Processed 583/1186 scans...
# Processed 584/1186 scans...
# Processed 585/1186 scans...
# Processed 586/1186 scans...
# Processed 587/1186 scans...
# Processed 588/1186 scans...
# Processed 589/1186 scans...
# Processed 590/1186 scans...
# Processed 591/1186 scans...
# Processed 592/1186 scans...
# Processed 593/1186 scans...
# Processed 594/1186 scans...
# Processed 595/1186 scans...
# Processed 596/1186 scans...
# Processed 597/1186 scans...
# Processed 598/1186 scans...
# Processed 599/1186 scans...
# Processed 600/1186 scans...
# Processed 601/1186 scans...
# Processed 602/1186 scans...
# Processed 603/1186 scans...
# Processed 604/1186 scans...
# Processed 605/1186 scans...
# Processed 606/1186 scans...
# Processed 607/1186 scans...
# Processed 608/1186 scans...
# Processed 609/1186 scans...
# Processed 610/1186 scans...
# Processed 611/1186 scans...
# Processed 612/1186 scans...
# Processed 613/1186 scans...
# Processed 614/1186 scans...
# Processed 615/1186 scans...
# Processed 616/1186 scans...
# Processed 617/1186 scans...
# Processed 618/1186 scans...
# Processed 619/1186 scans...
# Processed 620/1186 scans...
# Processed 621/1186 scans...
# Processed 622/1186 scans...
# Processed 623/1186 scans...
# Processed 624/1186 scans...
# Processed 625/1186 scans...
# Processed 626/1186 scans...
# Processed 627/1186 scans...
# Processed 628/1186 scans...
# Processed 629/1186 scans...
# Processed 630/1186 scans...
# Processed 631/1186 scans...
# Processed 632/1186 scans...
# Processed 633/1186 scans...
# Processed 634/1186 scans...
# Processed 635/1186 scans...
# Processed 636/1186 scans...
# Processed 637/1186 scans...
# Processed 638/1186 scans...
# Processed 639/1186 scans...
# Processed 640/1186 scans...
# Processed 641/1186 scans...
# Processed 642/1186 scans...
# Processed 643/1186 scans...
# Processed 644/1186 scans...
# Processed 645/1186 scans...
# Processed 646/1186 scans...
# Processed 647/1186 scans...
# Processed 648/1186 scans...
# Processed 649/1186 scans...
# Processed 650/1186 scans...
# Processed 651/1186 scans...
# Processed 652/1186 scans...
# Processed 653/1186 scans...
# Processed 654/1186 scans...
# Processed 655/1186 scans...
# Processed 656/1186 scans...
# Processed 657/1186 scans...
# Processed 658/1186 scans...
# Processed 659/1186 scans...
# Processed 660/1186 scans...
# Processed 661/1186 scans...
# Processed 662/1186 scans...
# Processed 663/1186 scans...
# Processed 664/1186 scans...
# Processed 665/1186 scans...
# Processed 666/1186 scans...
# Processed 667/1186 scans...
# Processed 668/1186 scans...
# Processed 669/1186 scans...
# Processed 670/1186 scans...
# Processed 671/1186 scans...
# Processed 672/1186 scans...
# Processed 673/1186 scans...
# Processed 674/1186 scans...
# Processed 675/1186 scans...
# Processed 676/1186 scans...
# Processed 677/1186 scans...
# Processed 678/1186 scans...
# Processed 679/1186 scans...
# Processed 680/1186 scans...
# Processed 681/1186 scans...
# Processed 682/1186 scans...
# Processed 683/1186 scans...
# Processed 684/1186 scans...
# Processed 685/1186 scans...
# Processed 686/1186 scans...
# Processed 687/1186 scans...
# Processed 688/1186 scans...
# Processed 689/1186 scans...
# Processed 690/1186 scans...
# Processed 691/1186 scans...
# Processed 692/1186 scans...
# Processed 693/1186 scans...
# Processed 694/1186 scans...
# Processed 695/1186 scans...
# Processed 696/1186 scans...
# Processed 697/1186 scans...
# Processed 698/1186 scans...
# Processed 699/1186 scans...
# Processed 700/1186 scans...
# Processed 701/1186 scans...
# Processed 702/1186 scans...
# Processed 703/1186 scans...
# Processed 704/1186 scans...
# Processed 705/1186 scans...
# Processed 706/1186 scans...
# Processed 707/1186 scans...
# Processed 708/1186 scans...
# Processed 709/1186 scans...
# Processed 710/1186 scans...
# Processed 711/1186 scans...
# Processed 712/1186 scans...
# Processed 713/1186 scans...
# Processed 714/1186 scans...
# Processed 715/1186 scans...
# Processed 716/1186 scans...
# Processed 717/1186 scans...
# Processed 718/1186 scans...
# Processed 719/1186 scans...
# Processed 720/1186 scans...
# Processed 721/1186 scans...
# Processed 722/1186 scans...
# Processed 723/1186 scans...
# Processed 724/1186 scans...
# Processed 725/1186 scans...
# Processed 726/1186 scans...
# Processed 727/1186 scans...
# Processed 728/1186 scans...
# Processed 729/1186 scans...
# Processed 730/1186 scans...
# Processed 731/1186 scans...
# Processed 732/1186 scans...
# Processed 733/1186 scans...
# Processed 734/1186 scans...
# Processed 735/1186 scans...
# Processed 736/1186 scans...
# Processed 737/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.282512043257574309474415322775: index can't contain negative values
# Processed 738/1186 scans...
# Processed 739/1186 scans...
# Processed 740/1186 scans...
# Processed 741/1186 scans...
# Processed 742/1186 scans...
# Processed 743/1186 scans...
# Processed 744/1186 scans...
# Processed 745/1186 scans...
# Processed 746/1186 scans...
# Processed 747/1186 scans...
# Processed 748/1186 scans...
# Processed 749/1186 scans...
# Processed 750/1186 scans...
# Processed 751/1186 scans...
# Processed 752/1186 scans...
# Processed 753/1186 scans...
# Processed 754/1186 scans...
# Processed 755/1186 scans...
# Processed 756/1186 scans...
# Processed 757/1186 scans...
# Processed 758/1186 scans...
# Processed 759/1186 scans...
# Processed 760/1186 scans...
# Processed 761/1186 scans...
# Processed 762/1186 scans...
# Processed 763/1186 scans...
# Processed 764/1186 scans...
# Processed 765/1186 scans...
# Processed 766/1186 scans...
# Processed 767/1186 scans...
# Processed 768/1186 scans...
# Processed 769/1186 scans...
# Processed 770/1186 scans...
# Processed 771/1186 scans...
# Processed 772/1186 scans...
# Processed 773/1186 scans...
# Processed 774/1186 scans...
# Processed 775/1186 scans...
# Processed 776/1186 scans...
# Processed 777/1186 scans...
# Processed 778/1186 scans...
# Processed 779/1186 scans...
# Processed 780/1186 scans...
# Processed 781/1186 scans...
# Processed 782/1186 scans...
# Processed 783/1186 scans...
# Processed 784/1186 scans...
# Processed 785/1186 scans...
# Processed 786/1186 scans...
# Processed 787/1186 scans...
# Processed 788/1186 scans...
# Processed 789/1186 scans...
# Processed 790/1186 scans...
# Processed 791/1186 scans...
# Processed 792/1186 scans...
# Processed 793/1186 scans...
# Processed 794/1186 scans...
# Processed 795/1186 scans...
# Processed 796/1186 scans...
# Processed 797/1186 scans...
# Processed 798/1186 scans...
# Processed 799/1186 scans...
# Processed 800/1186 scans...
# Processed 801/1186 scans...
# Processed 802/1186 scans...
# Processed 803/1186 scans...
# Processed 804/1186 scans...
# Processed 805/1186 scans...
# Processed 806/1186 scans...
# Processed 807/1186 scans...
# Processed 808/1186 scans...
# Processed 809/1186 scans...
# Processed 810/1186 scans...
# Processed 811/1186 scans...
# Processed 812/1186 scans...
# Processed 813/1186 scans...
# Processed 814/1186 scans...
# Processed 815/1186 scans...
# Processed 816/1186 scans...
# Processed 817/1186 scans...
# Processed 818/1186 scans...
# Processed 819/1186 scans...
# Processed 820/1186 scans...
# Processed 821/1186 scans...
# Processed 822/1186 scans...
# Processed 823/1186 scans...
# Processed 824/1186 scans...
# Processed 825/1186 scans...
# Processed 826/1186 scans...
# Processed 827/1186 scans...
# Processed 828/1186 scans...
# Processed 829/1186 scans...
# Processed 830/1186 scans...
# Processed 831/1186 scans...
# Processed 832/1186 scans...
# Processed 833/1186 scans...
# Processed 834/1186 scans...
# Processed 835/1186 scans...
# Processed 836/1186 scans...
# Processed 837/1186 scans...
# Processed 838/1186 scans...
# Processed 839/1186 scans...
# Processed 840/1186 scans...
# Processed 841/1186 scans...
# Processed 842/1186 scans...
# Processed 843/1186 scans...
# Processed 844/1186 scans...
# Processed 845/1186 scans...
# Processed 846/1186 scans...
# Processed 847/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.312127933722985204808706697221: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.312127933722985204808706697221: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.312127933722985204808706697221: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.312127933722985204808706697221: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.312127933722985204808706697221: index can't contain negative values
# Processed 848/1186 scans...
# Processed 849/1186 scans...
# Processed 850/1186 scans...
# Processed 851/1186 scans...
# Processed 852/1186 scans...
# Processed 853/1186 scans...
# Processed 854/1186 scans...
# Processed 855/1186 scans...
# Processed 856/1186 scans...
# Processed 857/1186 scans...
# Processed 858/1186 scans...
# Processed 859/1186 scans...
# Processed 860/1186 scans...
# Processed 861/1186 scans...
# Processed 862/1186 scans...
# Processed 863/1186 scans...
# Processed 864/1186 scans...
# Processed 865/1186 scans...
# Processed 866/1186 scans...
# Processed 867/1186 scans...
# Processed 868/1186 scans...
# Processed 869/1186 scans...
# Processed 870/1186 scans...
# Processed 871/1186 scans...
# Processed 872/1186 scans...
# Processed 873/1186 scans...
# Processed 874/1186 scans...
# Processed 875/1186 scans...
# Processed 876/1186 scans...
# Processed 877/1186 scans...
# Processed 878/1186 scans...
# Processed 879/1186 scans...
# Processed 880/1186 scans...
# Processed 881/1186 scans...
# Processed 882/1186 scans...
# Processed 883/1186 scans...
# Processed 884/1186 scans...
# Processed 885/1186 scans...
# Processed 886/1186 scans...
# Processed 887/1186 scans...
# Processed 888/1186 scans...
# Processed 889/1186 scans...
# Processed 890/1186 scans...
# Processed 891/1186 scans...
# Processed 892/1186 scans...
# Processed 893/1186 scans...
# Processed 894/1186 scans...
# Processed 895/1186 scans...
# Processed 896/1186 scans...
# Processed 897/1186 scans...
# Processed 898/1186 scans...
# Processed 899/1186 scans...
# Processed 900/1186 scans...
# Processed 901/1186 scans...
# Processed 902/1186 scans...
# Processed 903/1186 scans...
# Processed 904/1186 scans...
# Processed 905/1186 scans...
# Processed 906/1186 scans...
# Processed 907/1186 scans...
# Processed 908/1186 scans...
# Processed 909/1186 scans...
# Processed 910/1186 scans...
# Processed 911/1186 scans...
# Processed 912/1186 scans...
# Processed 913/1186 scans...
# Processed 914/1186 scans...
# Processed 915/1186 scans...
# Processed 916/1186 scans...
# Processed 917/1186 scans...
# Processed 918/1186 scans...
# Processed 919/1186 scans...
# Processed 920/1186 scans...
# Processed 921/1186 scans...
# Processed 922/1186 scans...
# Processed 923/1186 scans...
# Processed 924/1186 scans...
# Processed 925/1186 scans...
# Processed 926/1186 scans...
# Processed 927/1186 scans...
# Processed 928/1186 scans...
# Processed 929/1186 scans...
# Processed 930/1186 scans...
# Processed 931/1186 scans...
# Processed 932/1186 scans...
# Processed 933/1186 scans...
# Processed 934/1186 scans...
# Processed 935/1186 scans...
# Processed 936/1186 scans...
# Processed 937/1186 scans...
# Processed 938/1186 scans...
# Processed 939/1186 scans...
# Processed 940/1186 scans...
# Processed 941/1186 scans...
# Processed 942/1186 scans...
# Processed 943/1186 scans...
# Processed 944/1186 scans...
# Processed 945/1186 scans...
# Processed 946/1186 scans...
# Processed 947/1186 scans...
# Processed 948/1186 scans...
# Processed 949/1186 scans...
# Processed 950/1186 scans...
# Processed 951/1186 scans...
# Processed 952/1186 scans...
# Processed 953/1186 scans...
# Processed 954/1186 scans...
# Processed 955/1186 scans...
# Processed 956/1186 scans...
# Processed 957/1186 scans...
# Processed 958/1186 scans...
# Processed 959/1186 scans...
# Processed 960/1186 scans...
# Processed 961/1186 scans...
# Processed 962/1186 scans...
# Processed 963/1186 scans...
# Processed 964/1186 scans...
# Processed 965/1186 scans...
# Processed 966/1186 scans...
# Processed 967/1186 scans...
# Processed 968/1186 scans...
# Processed 969/1186 scans...
# Processed 970/1186 scans...
# Processed 971/1186 scans...
# Processed 972/1186 scans...
# Processed 973/1186 scans...
# Processed 974/1186 scans...
# Processed 975/1186 scans...
# Processed 976/1186 scans...
# Processed 977/1186 scans...
# Processed 978/1186 scans...
# Processed 979/1186 scans...
# Processed 980/1186 scans...
# Processed 981/1186 scans...
# Processed 982/1186 scans...
# Processed 983/1186 scans...
# Processed 984/1186 scans...
# Processed 985/1186 scans...
# Processed 986/1186 scans...
# Processed 987/1186 scans...
# Processed 988/1186 scans...
# Processed 989/1186 scans...
# Processed 990/1186 scans...
# Processed 991/1186 scans...
# Processed 992/1186 scans...
# Processed 993/1186 scans...
# Processed 994/1186 scans...
# Processed 995/1186 scans...
# Processed 996/1186 scans...
# Processed 997/1186 scans...
# Processed 998/1186 scans...
# Processed 999/1186 scans...
# Processed 1000/1186 scans...
# Processed 1001/1186 scans...
# Processed 1002/1186 scans...
# Processed 1003/1186 scans...
# Processed 1004/1186 scans...
# Processed 1005/1186 scans...
# Processed 1006/1186 scans...
# Processed 1007/1186 scans...
# Processed 1008/1186 scans...
# Processed 1009/1186 scans...
# Processed 1010/1186 scans...
# Processed 1011/1186 scans...
# Processed 1012/1186 scans...
# Processed 1013/1186 scans...
# Processed 1014/1186 scans...
# Processed 1015/1186 scans...
# Processed 1016/1186 scans...
# Processed 1017/1186 scans...
# Processed 1018/1186 scans...
# Processed 1019/1186 scans...
# Processed 1020/1186 scans...
# Processed 1021/1186 scans...
# Processed 1022/1186 scans...
# Processed 1023/1186 scans...
# Processed 1024/1186 scans...
# Processed 1025/1186 scans...
# Processed 1026/1186 scans...
# Processed 1027/1186 scans...
# Processed 1028/1186 scans...
# Processed 1029/1186 scans...
# Processed 1030/1186 scans...
# Processed 1031/1186 scans...
# Processed 1032/1186 scans...
# Processed 1033/1186 scans...
# Processed 1034/1186 scans...
# Processed 1035/1186 scans...
# Processed 1036/1186 scans...
# Processed 1037/1186 scans...
# Processed 1038/1186 scans...
# Processed 1039/1186 scans...
# Processed 1040/1186 scans...
# Processed 1041/1186 scans...
# Processed 1042/1186 scans...
# Processed 1043/1186 scans...
# Processed 1044/1186 scans...
# Processed 1045/1186 scans...
# Processed 1046/1186 scans...
# Processed 1047/1186 scans...
# Processed 1048/1186 scans...
# Processed 1049/1186 scans...
# Processed 1050/1186 scans...
# Processed 1051/1186 scans...
# Processed 1052/1186 scans...
# Processed 1053/1186 scans...
# Processed 1054/1186 scans...
# Processed 1055/1186 scans...
# Processed 1056/1186 scans...
# Processed 1057/1186 scans...
# Processed 1058/1186 scans...
# Processed 1059/1186 scans...
# Processed 1060/1186 scans...
# Processed 1061/1186 scans...
# Processed 1062/1186 scans...
# Processed 1063/1186 scans...
# Processed 1064/1186 scans...
# Processed 1065/1186 scans...
# Processed 1066/1186 scans...
# Processed 1067/1186 scans...
# Processed 1068/1186 scans...
# Processed 1069/1186 scans...
# Processed 1070/1186 scans...
# Processed 1071/1186 scans...
# Processed 1072/1186 scans...
# Processed 1073/1186 scans...
# Processed 1074/1186 scans...
# Processed 1075/1186 scans...
# Processed 1076/1186 scans...
# Processed 1077/1186 scans...
# Processed 1078/1186 scans...
# Processed 1079/1186 scans...
# Processed 1080/1186 scans...
# Processed 1081/1186 scans...
# Processed 1082/1186 scans...
# Processed 1083/1186 scans...
# Processed 1084/1186 scans...
# Processed 1085/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.801945620899034889998809817499: index can't contain negative values
# Processed 1086/1186 scans...
# Processed 1087/1186 scans...
# Processed 1088/1186 scans...
# Processed 1089/1186 scans...
# Processed 1090/1186 scans...
# Processed 1091/1186 scans...
# Processed 1092/1186 scans...
# Processed 1093/1186 scans...
# Processed 1094/1186 scans...
# Processed 1095/1186 scans...
# Processed 1096/1186 scans...
# Processed 1097/1186 scans...
# Processed 1098/1186 scans...
# Processed 1099/1186 scans...
# Processed 1100/1186 scans...
# Processed 1101/1186 scans...
# Processed 1102/1186 scans...
# Processed 1103/1186 scans...
# Processed 1104/1186 scans...
# Processed 1105/1186 scans...
# Processed 1106/1186 scans...
# Processed 1107/1186 scans...
# Processed 1108/1186 scans...
# Processed 1109/1186 scans...
# Processed 1110/1186 scans...
# Processed 1111/1186 scans...
# Processed 1112/1186 scans...
# Processed 1113/1186 scans...
# Processed 1114/1186 scans...
# Processed 1115/1186 scans...
# Processed 1116/1186 scans...
# Processed 1117/1186 scans...
# Processed 1118/1186 scans...
# Processed 1119/1186 scans...
# Processed 1120/1186 scans...
# Processed 1121/1186 scans...
# Processed 1122/1186 scans...
# Processed 1123/1186 scans...
# Processed 1124/1186 scans...
# Processed 1125/1186 scans...
# Processed 1126/1186 scans...
# Processed 1127/1186 scans...
# Processed 1128/1186 scans...
# Processed 1129/1186 scans...
# Processed 1130/1186 scans...
# Processed 1131/1186 scans...
# Processed 1132/1186 scans...
# Processed 1133/1186 scans...
# Processed 1134/1186 scans...
# Processed 1135/1186 scans...
# Processed 1136/1186 scans...
# Processed 1137/1186 scans...
# Processed 1138/1186 scans...
# Processed 1139/1186 scans...
# Processed 1140/1186 scans...
# Processed 1141/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311: index can't contain negative values
# Processed 1142/1186 scans...
# Processed 1143/1186 scans...
# Processed 1144/1186 scans...
# Processed 1145/1186 scans...
# Processed 1146/1186 scans...
# Processed 1147/1186 scans...
# Processed 1148/1186 scans...
# Processed 1149/1186 scans...
# Processed 1150/1186 scans...
# Processed 1151/1186 scans...
# Processed 1152/1186 scans...
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877: index can't contain negative values
# Error processing 1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877: index can't contain negative values
# Processed 1153/1186 scans...
# Processed 1154/1186 scans...
# Processed 1155/1186 scans...
# Processed 1156/1186 scans...
# Processed 1157/1186 scans...
# Processed 1158/1186 scans...
# Processed 1159/1186 scans...
# Processed 1160/1186 scans...
# Processed 1161/1186 scans...
# Processed 1162/1186 scans...
# Processed 1162 positive patches from 1162 scans.

# %%
df_candidates = pd.read_csv(CANDIDATES_PATH)
print("Processing negative samples (non-nodules)...")
negative_patches = []
processed_neg_scans = 0

if not df_candidates.empty:
    negative_candidates = df_candidates[df_candidates['class'] == 0]  # Filter non-nodules
    total_neg_samples = len(negative_candidates)  # Total negatives to process

    for idx, row in negative_candidates.iterrows():
        seriesuid = row['seriesuid']
        world_coords = row[['coordX', 'coordY', 'coordZ']].values

        # Find and load the image
        mhd_file = None
        for subset_path in SUBSET_PATHS:
            potential_file = os.path.join(subset_path, f"{seriesuid}.mhd")
            if os.path.exists(potential_file):
                mhd_file = potential_file
                break

        if not mhd_file: continue  # Skip if file not found

        try:
            image_array, origin, spacing, direction = load_itk_image(mhd_file)

            # Preprocess: Resample -> Normalize
            resampled_img, new_spacing = resample_image(image_array, spacing, TARGET_SPACING)
            normalized_img = normalize_hu(resampled_img)

            # Adjust coordinates
            new_voxel_coords = world_to_voxel(world_coords, origin, new_spacing, direction)

            # Extract patch
            patch = extract_patch(normalized_img, new_voxel_coords, patch_size=PATCH_SIZE)
            negative_patches.append(patch)
            processed_neg_scans += 1

            # Print progress
            if processed_neg_scans % 10 == 0:  # Print every 10 samples
                print(f"Processed {processed_neg_scans}/{total_neg_samples} negative samples...")

        except Exception as e:
            print(f"Error processing {seriesuid}: {e}")

    print(f"Processed {len(negative_patches)} negative patches from {processed_neg_scans} scans.")
# Out:
# Processing negative samples (non-nodules)...
# Processed 10/549714 negative samples...
# Processed 20/549714 negative samples...
# Processed 30/549714 negative samples...
# Processed 40/549714 negative samples...
# Processed 50/549714 negative samples...
# Processed 60/549714 negative samples...
# Processed 70/549714 negative samples...
# Processed 80/549714 negative samples...
# Processed 90/549714 negative samples...
# Processed 100/549714 negative samples...
# Processed 110/549714 negative samples...
# Processed 120/549714 negative samples...
# Processed 130/549714 negative samples...
# Processed 140/549714 negative samples...
# Processed 150/549714 negative samples...
# Processed 160/549714 negative samples...
# Processed 170/549714 negative samples...
# Processed 180/549714 negative samples...
# Processed 190/549714 negative samples...
# Processed 200/549714 negative samples...
# Processed 210/549714 negative samples...
# Processed 220/549714 negative samples...
# Processed 230/549714 negative samples...
# Processed 240/549714 negative samples...
# Processed 250/549714 negative samples...
# Processed 260/549714 negative samples...
# Processed 270/549714 negative samples...
# Processed 280/549714 negative samples...
# Processed 290/549714 negative samples...
# Processed 300/549714 negative samples...
# Processed 310/549714 negative samples...
# Processed 320/549714 negative samples...
# Processed 330/549714 negative samples...
# Processed 340/549714 negative samples...
# Processed 350/549714 negative samples...
# Processed 360/549714 negative samples...
# Processed 370/549714 negative samples...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-348bc9af0168> in <cell line: 6>()
#      26
#      27             # Preprocess: Resample -> Normalize
# ---> 28             resampled_img, new_spacing = resample_image(image_array, spacing, TARGET_SPACING)
#      29             normalized_img = normalize_hu(resampled_img)
#      30
#
# <ipython-input-25-50867b01bc4a> in resample_image(image_array, spacing, new_spacing)
#      10
#      11     # Use spline interpolation (order=1 for linear, order=3 for cubic)
# ---> 12     resampled_image = zoom(image_array, real_resize_factor, order=1)
#      13
#      14     return resampled_image, new_spacing
#
# /usr/local/lib/python3.10/dist-packages/scipy/ndimage/_interpolation.py in zoom(input, zoom, output, order, mode, cval, prefilter, grid_mode)
#     867                         where=zoom_div != 0)
#     868     zoom = numpy.ascontiguousarray(zoom)
# --> 869     _nd_image.zoom_shift(filtered, zoom, None, output, order, mode, cval, npad,
#     870                          grid_mode)
#     871     return output
#
# KeyboardInterrupt:

# %%
df_candidates = pd.read_csv(CANDIDATES_PATH)
print("Processing negative samples (non-nodules)...")
negative_patches = []
processed_neg_scans = 0

if not df_candidates.empty:
    negative_candidates = df_candidates[df_candidates['class'] == 0]  # Filter non-nodules
    total_neg_samples = len(negative_candidates)  # Total negatives to process

    # Set a limit of 20 samples
    max_samples = 20

    for idx, row in negative_candidates.iterrows():
        if processed_neg_scans >= max_samples:
            break  # Stop after processing 20 samples

        seriesuid = row['seriesuid']
        world_coords = row[['coordX', 'coordY', 'coordZ']].values

        # Find and load the image
        mhd_file = None
        for subset_path in SUBSET_PATHS:
            potential_file = os.path.join(subset_path, f"{seriesuid}.mhd")
            if os.path.exists(potential_file):
                mhd_file = potential_file
                break

        if not mhd_file:
            continue  # Skip if file not found

        try:
            image_array, origin, spacing, direction = load_itk_image(mhd_file)

            # Preprocess: Resample -> Normalize
            resampled_img, new_spacing = resample_image(image_array, spacing, TARGET_SPACING)
            normalized_img = normalize_hu(resampled_img)

            # Adjust coordinates
            new_voxel_coords = world_to_voxel(world_coords, origin, new_spacing, direction)

            # Extract patch
            patch = extract_patch(normalized_img, new_voxel_coords, patch_size=PATCH_SIZE)
            negative_patches.append(patch)
            processed_neg_scans += 1

            # Print progress
            if processed_neg_scans % 10 == 0:  # Print every 10 samples
                print(f"Processed {processed_neg_scans}/{total_neg_samples} negative samples...")

        except Exception as e:
            print(f"Error processing {seriesuid}: {e}")

    print(f"Processed {len(negative_patches)} negative patches from {processed_neg_scans} scans.")
# Out:
# Processing negative samples (non-nodules)...
# Processed 10/549714 negative samples...
# Processed 20/549714 negative samples...
# Processed 20 negative patches from 20 scans.

# %%
# Create the labels for the positive and negative patches
positive_labels = np.ones(num_positive_patches)  # All positive patches have label 1
negative_labels = np.zeros(num_negative_patches)  # All negative patches have label 0

# Combine the patches and labels
X = np.array(positive_patches + negative_patches)
y = np.concatenate([positive_labels, negative_labels])  # Combine labels for both positive and negative patches

# Ensure y is an integer type before using np.bincount
y = y.astype(int)

# Add channel dimension for DL models (e.g., TensorFlow/Keras: samples, z, y, x, channels)
X = np.expand_dims(X, axis=-1)

# Print dataset details
print(f"Number of positive patches: {num_positive_patches}")
print(f"Number of negative patches: {num_negative_patches}")
print(f"Final dataset shape: X={X.shape}, y={y.shape}")
print(f"Class distribution: {np.bincount(y)}")
# Out:
# Number of positive patches: 1162
# Number of negative patches: 20
# Final dataset shape: X=(1182, 48, 48, 48, 1), y=(1182,)
# Class distribution: [  20 1162]

# %%
# --- Process Negative Samples ---
# This is more complex. Need to sample locations *away* from known nodules.
# Options:
# 1. Use `candidates.csv` 'class 0' entries if available.
# 2. Randomly sample locations within the lung masks (if segmentation is done).
# 3. Randomly sample locations and check distance from known nodules.
# Aim for a balanced or slightly majority-negative dataset (e.g., 1:1 or 1:3 positive:negative ratio).

print("Negative sampling needs implementation (using candidates.csv or random sampling).")
# Placeholder: Assume we have generated 'negative_patches' somehow
# negative_patches = [...]
# labels.extend([0] * len(negative_patches))

# Combine and shuffle
X = np.array(positive_patches + negative_patches)
y = np.array(labels)

# Add channel dimension for DL models (e.g., TensorFlow/Keras: samples, z, y, x, channels)
X = np.expand_dims(X, axis=-1)

print(f"Final dataset shape: X={X.shape}, y={y.shape}")
print(f"Class distribution: {np.bincount(y)}")
# Out:
# Negative sampling needs implementation (using candidates.csv or random sampling).
# Final dataset shape: X=(1182, 48, 48, 48, 1), y=(1162,)
# Class distribution: [   0 1162]

# %%
import numpy as np

# Save the positive patches, negative patches, and labels as .npy files
np.save('/kaggle/working/positive_patches.npy', positive_patches)
np.save('/kaggle/working/negative_patches.npy', negative_patches)
np.save('/kaggle/working/labels.npy', labels)

print("Preprocessing results saved.")
# Out:
# Preprocessing results saved.

# %%
#positive_patches = np.load('positive_patches.npy')
#negative_patches = np.load('negative_patches.npy')
#labels = np.load('labels.npy')

# %%
from sklearn.model_selection import train_test_split

# Ensure X and y are defined
if 'X' in locals() and 'y' in locals() and len(X) > 0:
    # Split the dataset into training, validation, and test sets
    X_train_val, X_test, y_train_val, y_test = train_test_split(
        X, y, test_size=0.15, random_state=42, stratify=y
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_val, y_train_val, test_size=0.15, random_state=42, stratify=y_train_val  # Adjusted split ratio
    )
    
    # Print the shapes of the splits
    print(f"Train set: {X_train.shape}, {y_train.shape}")
    print(f"Validation set: {X_val.shape}, {y_val.shape}")
    print(f"Test set: {X_test.shape}, {y_test.shape}")
else:
    print("X and y are not defined. Skipping data splitting.")
# Out:
# Train set: (853, 48, 48, 48, 1), (853,)
# Validation set: (151, 48, 48, 48, 1), (151,)
# Test set: (178, 48, 48, 48, 1), (178,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_3d_cnn(input_shape, num_classes=1): # num_classes=1 for binary (sigmoid output)
    """Builds a simple 3D CNN model."""
    model = models.Sequential(name="3D_CNN")

    model.add(layers.Input(shape=input_shape))

    # Block 1
    model.add(layers.Conv3D(32, kernel_size=(3, 3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Block 2
    model.add(layers.Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Block 3
    model.add(layers.Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Flatten and Dense Layers
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.3))

    # Output Layer
    # Use 'sigmoid' for binary classification
    output_activation = 'sigmoid' if num_classes == 1 else 'softmax'
    model.add(layers.Dense(num_classes, activation=output_activation))

    return model

# %%
if 'X_train' in locals() and len(X_train) > 0:
    INPUT_SHAPE = X_train.shape[1:] # (z, y, x, channels)
    model = build_3d_cnn(INPUT_SHAPE)
    model.summary()
else:
     print("Skipping model instantiation as training data is not ready.")
     # Define dummy shape if needed for subsequent cells
     # INPUT_SHAPE = (PATCH_SIZE[0], PATCH_SIZE[1], PATCH_SIZE[2], 1)
     # model = build_3d_cnn(INPUT_SHAPE)
     # model.summary()
# Out:
# Model: "3D_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                      │ (None, 48, 48, 48, 32)      │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 48, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 24, 24, 24, 32)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_1 (Conv3D)                    │ (None, 24, 24, 24, 64)      │          55,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 24, 24, 64)      │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 12, 12, 12, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_2 (Conv3D)                    │ (None, 12, 12, 12, 128)     │         221,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 12, 12, 128)     │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_2 (MaxPooling3D)       │ (None, 6, 6, 6, 128)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 27648)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,539,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,825,857 (14.59 MB)
#  Trainable params: 3,825,409 (14.59 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# ### 3.2 Compile the Model
# Choose an optimizer, loss function, and metrics. Use binary cross-entropy for binary classification.

if 'model' in locals():
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    loss = tf.keras.losses.BinaryCrossentropy()
    metrics = [
         'accuracy',
         tf.keras.metrics.Precision(name='precision'),
         tf.keras.metrics.Recall(name='recall'),
         tf.keras.metrics.AUC(name='auc')
     ]
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    print("Model compiled successfully.")
else:
    print("Skipping model compilation as the model is not defined.")
# Out:
# Model compiled successfully.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

EPOCHS = 2 # Adjust as needed
BATCH_SIZE = 16 # Adjust based on available memory

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ModelCheckpoint('/kaggle/working/best_nodule_classifier.keras', monitor='val_loss', save_best_only=True, verbose=1)
]

# Check if training data exists before fitting
if 'X_train' in locals() and 'y_train' in locals() and \
   'X_val' in locals() and 'y_val' in locals() and \
   len(X_train) > 0 and len(X_val) > 0 and 'model' in locals():

    print("Starting model training...")
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1 # Set to 1 or 2 for progress updates
    )
    print("Model training finished.")

    # Plot training history
    pd.DataFrame(history.history).plot(figsize=(12, 8))
    plt.title('Model Training History')
    plt.ylabel('Metric Value')
    plt.xlabel('Epoch')
    plt.ylim(0, 1) # Adjust ylim if necessary
    plt.grid(True)
    plt.show()

else:
    print("Skipping model training as data or model is not available.")
    history = None # Define history as None if training didn't run
# Out:
# Starting model training...
# Epoch 1/2
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.9697 - auc: 0.5753 - loss: 0.2763 - precision: 0.9854 - recall: 0.9837
# Epoch 1: val_loss improved from inf to 0.26893, saving model to best_nodule_classifier.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 486s 9s/step - accuracy: 0.9697 - auc: 0.5752 - loss: 0.2767 - precision: 0.9854 - recall: 0.9837 - val_accuracy: 0.9801 - val_auc: 0.4381 - val_loss: 0.2689 - val_precision: 0.9801 - val_recall: 1.0000
# Epoch 2/2
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9811 - auc: 0.5420 - loss: 0.2114 - precision: 0.9878 - recall: 0.9931
# Epoch 2: val_loss improved from 0.26893 to 0.25571, saving model to best_nodule_classifier.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 477s 9s/step - accuracy: 0.9809 - auc: 0.5415 - loss: 0.2124 - precision: 0.9878 - recall: 0.9929 - val_accuracy: 0.9801 - val_auc: 0.5878 - val_loss: 0.2557 - val_precision: 0.9801 - val_recall: 1.0000
# Restoring model weights from the end of the best epoch: 2.
# Model training finished.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

if os.path.exists('best_nodule_classifier.keras'):
     print("Loading best saved model weights...")
     model.load_weights('best_nodule_classifier.keras')

if 'model' in locals() and 'X_test' in locals() and 'y_test' in locals() and len(X_test) > 0:
    print("\nEvaluating model on the test set...")
    results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=1)

    print("\nTest Set Evaluation Results:")
    metric_names = ['Loss', 'Accuracy', 'Precision', 'Recall', 'AUC'] 
    for name, value in zip(metric_names, results):
        print(f"{name}: {value:.4f}")
else:
    print("Skipping model evaluation as model or test data is not available.")

if 'model' in locals() and 'X_test' in locals() and 'y_test' in locals() and len(X_test) > 0:
    y_pred_proba = model.predict(X_test, batch_size=BATCH_SIZE).flatten()
    y_pred_labels = (y_pred_proba > 0.5).astype(int)

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred_labels, target_names=['Non-Nodule (0)', 'Nodule (1)']))

    cm = confusion_matrix(y_test, y_pred_labels)
    print("\nConfusion Matrix:")
    print(cm)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Predicted Non-Nodule', 'Predicted Nodule'],
                yticklabels=['Actual Non-Nodule', 'Actual Nodule'])
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Class')
    plt.xlabel('Predicted Class')
    plt.show()

    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

else:
    print("Skipping detailed evaluation as predictions could not be generated.")
# Out:
# Loading best saved model weights...
#
# Evaluating model on the test set...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9859 - auc: 0.5027 - loss: 0.2433 - precision: 0.9859 - recall: 1.0000
#
# Test Set Evaluation Results:
# Loss: 0.2480
# Accuracy: 0.9831
# Precision: 0.9831
# Recall: 1.0000
# AUC: 0.6400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Non-Nodule (0)       0.00      0.00      0.00         3
#     Nodule (1)       0.98      1.00      0.99       175
#
#       accuracy                           0.98       178
#      macro avg       0.49      0.50      0.50       178
#   weighted avg       0.97      0.98      0.97       178
#
#
# Confusion Matrix:
# [[  0   3]
#  [  0 175]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
