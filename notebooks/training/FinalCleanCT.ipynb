# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
                                     BatchNormalization, GlobalAveragePooling2D, Input)
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.applications import MobileNetV2, ResNet50
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (EarlyStopping, ModelCheckpoint, ReduceLROnPlateau,
                                        Callback)
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score,
                             cohen_kappa_score, accuracy_score, precision_recall_fscore_support)
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.metrics import Precision, Recall, AUC
import warnings
import logging

# Ignore warnings for cleaner output
warnings.filterwarnings('ignore')
# Set TensorFlow logging level to suppress unnecessary messages
tf.get_logger().setLevel(logging.ERROR)

# %%
# --- Configuration ---
DATA_DIR = r'/content/drive/MyDrive/Datasets/Chest CT-Scan images Dataset' # Change if needed
IMG_HEIGHT, IMG_WIDTH = 224, 224  # Target image dimensions (standard for many pre-trained models)
BATCH_SIZE = 16                   # Number of samples per gradient update
SEED = 42                         # Random seed for reproducibility
VAL_SPLIT = 0.20                  # Proportion of data for validation (used for simple split)
N_SPLITS_KFOLD = 5                # Number of folds for K-Fold Cross-Validation

# Training parameters (can be adjusted)
INITIAL_EPOCHS = 50              # Max epochs for initial transfer learning phase
FINETUNE_EPOCHS = 30             # Max epochs for fine-tuning phase
CNN_EPOCHS = 75                  # Max epochs for custom CNN training

INITIAL_LR = 1e-3                 # Initial learning rate for transfer learning
FINETUNE_LR = 1e-5                # Learning rate for fine-tuning
CNN_LR = 1e-4                     # Learning rate for custom CNN

# Callbacks configuration
EARLY_STOPPING_PATIENCE = 10      # Stop training if no improvement after this many epochs
REDUCE_LR_PATIENCE = 5            # Reduce LR if no improvement after this many epochs
REDUCE_LR_FACTOR = 0.2            # Factor by which to reduce LR

# Model checkpoint paths
CNN_MODEL_PATH = '/content/drive/MyDrive/ctmodels/best_cnn_model.keras'
MOBILENET_MODEL_PATH = '/content/drive/MyDrive/ctmodels/best_mobilenet_model.keras'
RESNET_MODEL_PATH = '/content/drive/MyDrive/ctmodels/best_resnet_model.keras'
KFOLD_MODEL_PATH_TEMPLATE = '/content/drive/MyDrive/ctmodels/best_resnet_kfold_split_{split}.keras'

# Set random seeds for reproducibility
np.random.seed(SEED)
tf.random.set_seed(SEED)

if not os.path.exists(DATA_DIR):
    print(f"Error: Data directory not found at {DATA_DIR}")
else:
    print(f"Data directory found: {DATA_DIR}")
# Out:
# Data directory found: /content/drive/MyDrive/Datasets/Chest CT-Scan images Dataset

# %%
classes = sorted([cls for cls in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, cls))])
print("\nClasses found:", classes)
num_classes = len(classes)
# Out:
# Classes found: ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']

# %%
if num_classes == 0:
    print("Error: No classes found in the dataset directory.")
else:
    # Store image counts per class
    class_counts = {}
    all_filepaths = []
    all_labels = []

    print("\nImage counts per class:")
    for i, cls in enumerate(classes):
        cls_path = os.path.join(DATA_DIR, cls)
        images = [img for img in os.listdir(cls_path) if img.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
        count = len(images)
        class_counts[cls] = count
        print(f"- {cls}: {count} images")
        # Store filepaths and labels for potential later use (e.g., KFold)
        for img_name in images:
            all_filepaths.append(os.path.join(cls_path, img_name))
            all_labels.append(cls) # Store class name as label

    # Create a DataFrame for easier handling (especially for KFold)
    df = pd.DataFrame({'filepath': all_filepaths, 'label': all_labels})
    print(f"\nTotal images found: {len(df)}")

    # --- Visualize Sample Images ---
    num_rows = (num_classes + 1) // 2
    plt.figure(figsize=(12, 4 * num_rows))
    plt.suptitle("Sample Images from Each Class", fontsize=16)

    for i, cls in enumerate(classes):
        plt.subplot(num_rows, 2, i + 1)
        # Find a valid image path for the current class
        first_image_path = df[df['label'] == cls]['filepath'].iloc[0]
        try:
            img = cv2.imread(first_image_path)
            if img is None:
                print(f"Warning: Failed to load sample image: {first_image_path}")
                plt.title(f"{cls}\n(Image Load Error)")
            else:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Convert BGR to RGB
                plt.imshow(img)
                plt.title(f"{cls}\n({class_counts[cls]} images)")
        except Exception as e:
            print(f"Error loading image {first_image_path}: {e}")
            plt.title(f"{cls}\n(Error: {e})")

        plt.axis('off')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap
    plt.show()

    # --- Visualize Class Distribution ---
    plt.figure(figsize=(10, 5))
    sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()))
    plt.title("Class Distribution")
    plt.xlabel("Class")
    plt.ylabel("Number of Images")
    plt.xticks(rotation=45, ha='right')
    plt.show()

    # Check for significant imbalance
    min_count = min(class_counts.values())
    max_count = max(class_counts.values())
    if max_count / min_count > 3: # Arbitrary threshold for imbalance warning
        print("\nWarning: Potential class imbalance detected.")
# Out:
# Image counts per class:
# - adenocarcinoma: 338 images
# - large.cell.carcinoma: 187 images
# - normal: 215 images
# - squamous.cell.carcinoma: 260 images
#
# Total images found: 1000

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,             # Normalize pixel values to [0, 1]
    rotation_range=20,        # Increased rotation range
    width_shift_range=0.15,   # Increased horizontal shift
    height_shift_range=0.15,  # Increased vertical shift
    shear_range=0.15,         # Increased shear intensity
    zoom_range=0.15,          # Increased zoom range
    horizontal_flip=True,     # Randomly flip images horizontally
    fill_mode='nearest',      # Strategy for filling pixels after transformations
    validation_split=VAL_SPLIT  # Reserve part of the data for validation
)

# Validation data should only be rescaled (no augmentation)
validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=VAL_SPLIT # Must specify split again for the validation generator
)

# %%
# Create Training Generator
print("\nCreating Training Generator:")
train_generator = train_datagen.flow_from_directory(
    DATA_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',   # For multi-class classification
    subset='training',          # Specify this is the training set
    seed=SEED,
    shuffle=True
)

# Create Validation Generator
print("\nCreating Validation Generator:")
validation_generator = validation_datagen.flow_from_directory(
    DATA_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',        # Specify this is the validation set
    seed=SEED,
    shuffle=False
)

# Verify class indices
print("\nClass Indices (should be consistent):")
print("Training Generator:", train_generator.class_indices)
print("Validation Generator:", validation_generator.class_indices)
class_indices = train_generator.class_indices
# Out:
# Creating Training Generator:
# Found 801 images belonging to 4 classes.
#
# Creating Validation Generator:
# Found 199 images belonging to 4 classes.
#
# Class Indices (should be consistent):
# Training Generator: {'adenocarcinoma': 0, 'large.cell.carcinoma': 1, 'normal': 2, 'squamous.cell.carcinoma': 3}
# Validation Generator: {'adenocarcinoma': 0, 'large.cell.carcinoma': 1, 'normal': 2, 'squamous.cell.carcinoma': 3}

# %%
# Calculate steps per epoch
steps_per_epoch = train_generator.samples // BATCH_SIZE
validation_steps = validation_generator.samples // BATCH_SIZE
if train_generator.samples % BATCH_SIZE != 0:
    steps_per_epoch += 1
if validation_generator.samples % BATCH_SIZE != 0:
    validation_steps += 1

print(f"\nTraining steps per epoch: {steps_per_epoch}")
print(f"Validation steps per epoch: {validation_steps}")
# Out:
# Training steps per epoch: 51
# Validation steps per epoch: 13

# %%
#  Model Definitions

def build_custom_cnn(input_shape, num_classes, learning_rate=CNN_LR):
    """Builds a custom CNN model."""
    model = Sequential([
        # Input Layer
        Input(shape=input_shape),

        # Block 1
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        SpatialDropout2D(0.25),

        # Block 2
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        SpatialDropout2D(0.25),

        # Block 3
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        SpatialDropout2D(0.25),

        # Fully Connected Layers
        GlobalAveragePooling2D(),
        Dense(256, activation='relu'), # Increased dense layer size
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')  # Output layer
    ], name="Custom_CNN")

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print("Custom CNN Model Built and Compiled.")
    model.summary()
    return model

# %%
def build_transfer_model(base_model_fn, input_shape, num_classes, trainable_base=False, learning_rate=INITIAL_LR, model_name="Transfer_Model"):
    """Builds a transfer learning model with a specified base."""
    base_model = base_model_fn(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = trainable_base # Control freezing/unfreezing

    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=trainable_base) # Use training=False if base is frozen
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x) # Slightly increased dropout
    x = Dense(256, activation='relu')(x) # Add an intermediate dense layer
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs, name=model_name)

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print(f"{model_name} Model Built and Compiled (Base Trainable: {trainable_base}).")
    model.summary()
    return model

# %%
#Training and Evaluation Utilities

# --- Callbacks ---
def get_callbacks(model_path, early_stopping_patience=EARLY_STOPPING_PATIENCE, reduce_lr_patience=REDUCE_LR_PATIENCE, reduce_lr_factor=REDUCE_LR_FACTOR, monitor='val_loss'):
    """Creates a list of standard callbacks."""
    early_stopping = EarlyStopping(
        monitor=monitor,
        patience=early_stopping_patience,
        restore_best_weights=True,
        verbose=1
    )
    model_checkpoint = ModelCheckpoint(
        filepath=model_path,
        monitor=monitor,
        save_best_only=True,
        verbose=1
    )
    reduce_lr = ReduceLROnPlateau(
        monitor=monitor,
        factor=reduce_lr_factor,
        patience=reduce_lr_patience,
        min_lr=1e-6, # Prevent LR from becoming too small
        verbose=1
    )
    return [early_stopping, model_checkpoint, reduce_lr]

# --- Plotting History ---
def plot_training_history(history, title_prefix=""):
    """Plots accuracy and loss curves from Keras history object."""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'{title_prefix}Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title(f'{title_prefix}Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.tight_layout()
    plt.show()

# --- Comprehensive Evaluation ---
def evaluate_model(model, generator, class_names):
    """Evaluates the model and returns comprehensive metrics."""
    print(f"\n--- Evaluating Model: {model.name} ---")
    generator.reset() # Ensure generator starts from the beginning

    # Predict probabilities
    y_pred_probs = model.predict(generator, steps=validation_steps, verbose=1)
    # Get predicted classes (indices)
    y_pred = np.argmax(y_pred_probs, axis=1)
    # Get true classes (indices)
    y_true = generator.classes[:len(y_pred)] # Ensure lengths match if generator doesn't perfectly divide

    if len(y_true) != len(y_pred):
         print(f"Warning: Mismatch in number of true labels ({len(y_true)}) and predictions ({len(y_pred)}). Adjusting...")
         min_len = min(len(y_true), len(y_pred))
         y_true = y_true[:min_len]
         y_pred = y_pred[:min_len]
         y_pred_probs = y_pred_probs[:min_len]


    # Calculate Metrics
    accuracy = accuracy_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)

    # Classification Report (precision, recall, f1-score)
    report_dict = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)
    report_str = classification_report(y_true, y_pred, target_names=class_names)

    # ROC-AUC Score (One-vs-Rest for multiclass)
    try:
        y_true_one_hot = to_categorical(y_true, num_classes=len(class_names))
        roc_auc = roc_auc_score(y_true_one_hot, y_pred_probs, multi_class='ovr', average='macro')
    except ValueError as e:
        print(f"Warning: Could not calculate ROC-AUC. Error: {e}. Setting ROC-AUC to NaN.")
        # This might happen if a class is missing in the validation subset predictions
        roc_auc = np.nan


    # Confusion Matrix
    conf_matrix = confusion_matrix(y_true, y_pred)

    # Print Metrics
    print(f"\nValidation Accuracy: {accuracy:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")
    print(f"Macro Avg ROC-AUC: {roc_auc:.4f}")
    print("\nClassification Report:")
    print(report_str)

    # Plot Confusion Matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f"Confusion Matrix - {model.name}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

    # Store results
    results = {
        'model_name': model.name,
        'accuracy': accuracy,
        'kappa': kappa,
        'roc_auc': roc_auc,
        'classification_report_dict': report_dict,
        'classification_report_str': report_str,
        'confusion_matrix': conf_matrix
    }
    return results

# Dictionary to store results from all models
all_model_results = {}

# %% [markdown]
# # Custom CNN

# %%
print("\n===== Training Custom CNN =====")
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# Build the model
cnn_model = build_custom_cnn(input_shape, num_classes, learning_rate=CNN_LR)

# Get callbacks
cnn_callbacks = get_callbacks(CNN_MODEL_PATH, monitor='val_accuracy') # Monitor accuracy for CNN

# Train the model
print("\nStarting Custom CNN Training...")
history_cnn = cnn_model.fit(
    train_generator,
    epochs=CNN_EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=cnn_callbacks,
    verbose=1 # Set to 1 or 2 for progress updates per epoch
)

# Plot history
plot_training_history(history_cnn, title_prefix="Custom CNN ")

# Load the best weights saved by ModelCheckpoint
print("\nLoading best weights for Custom CNN...")
cnn_model.load_weights(CNN_MODEL_PATH) # EarlyStopping already restored best weights, but this is safer

# Evaluate the best model
cnn_results = evaluate_model(cnn_model, validation_generator, classes)
all_model_results['CNN'] = cnn_results
# Out:
# ===== Training Custom CNN =====
# Custom CNN Model Built and Compiled.
# Model: "Custom_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d               │ (None, 112, 112, 32)   │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_1             │ (None, 56, 56, 64)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_2             │ (None, 28, 28, 128)    │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 323,876 (1.24 MB)
#  Trainable params: 322,468 (1.23 MB)
#  Non-trainable params: 1,408 (5.50 KB)
# Starting Custom CNN Training...
# Epoch 1/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3350 - loss: 1.9936
# Epoch 1: val_accuracy improved from -inf to 0.26131, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 217s 4s/step - accuracy: 0.3358 - loss: 1.9900 - val_accuracy: 0.2613 - val_loss: 1.4069 - learning_rate: 1.0000e-04
# Epoch 2/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4579 - loss: 1.5392
# Epoch 2: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.4574 - loss: 1.5413 - val_accuracy: 0.2462 - val_loss: 1.5914 - learning_rate: 1.0000e-04
# Epoch 3/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4325 - loss: 1.5875
# Epoch 3: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4323 - loss: 1.5875 - val_accuracy: 0.2362 - val_loss: 1.7109 - learning_rate: 1.0000e-04
# Epoch 4/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4581 - loss: 1.4736
# Epoch 4: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4583 - loss: 1.4732 - val_accuracy: 0.2613 - val_loss: 1.9181 - learning_rate: 1.0000e-04
# Epoch 5/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4200 - loss: 1.6469
# Epoch 5: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4202 - loss: 1.6457 - val_accuracy: 0.2613 - val_loss: 2.1406 - learning_rate: 1.0000e-04
# Epoch 6/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.4584 - loss: 1.4561
# Epoch 6: val_accuracy did not improve from 0.26131
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.4584 - loss: 1.4574 - val_accuracy: 0.2613 - val_loss: 2.4303 - learning_rate: 1.0000e-04
# Epoch 7/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.4178 - loss: 1.5731
# Epoch 7: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.4181 - loss: 1.5721 - val_accuracy: 0.2613 - val_loss: 2.3362 - learning_rate: 2.0000e-05
# Epoch 8/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4709 - loss: 1.4142
# Epoch 8: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.4708 - loss: 1.4144 - val_accuracy: 0.2613 - val_loss: 2.1276 - learning_rate: 2.0000e-05
# Epoch 9/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.4372 - loss: 1.4553
# Epoch 9: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 270ms/step - accuracy: 0.4378 - loss: 1.4546 - val_accuracy: 0.2613 - val_loss: 1.9414 - learning_rate: 2.0000e-05
# Epoch 10/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4265 - loss: 1.4848
# Epoch 10: val_accuracy did not improve from 0.26131
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4267 - loss: 1.4838 - val_accuracy: 0.2362 - val_loss: 1.6653 - learning_rate: 2.0000e-05
# Epoch 11/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4664 - loss: 1.3622
# Epoch 11: val_accuracy improved from 0.26131 to 0.34673, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.4667 - loss: 1.3610 - val_accuracy: 0.3467 - val_loss: 1.4101 - learning_rate: 2.0000e-05
# Epoch 12/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4772 - loss: 1.3140
# Epoch 12: val_accuracy improved from 0.34673 to 0.35176, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4770 - loss: 1.3154 - val_accuracy: 0.3518 - val_loss: 1.2073 - learning_rate: 2.0000e-05
# Epoch 13/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4326 - loss: 1.4319
# Epoch 13: val_accuracy improved from 0.35176 to 0.39196, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.4330 - loss: 1.4324 - val_accuracy: 0.3920 - val_loss: 1.0913 - learning_rate: 2.0000e-05
# Epoch 14/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4442 - loss: 1.3915
# Epoch 14: val_accuracy did not improve from 0.39196
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 265ms/step - accuracy: 0.4443 - loss: 1.3917 - val_accuracy: 0.3819 - val_loss: 0.9743 - learning_rate: 2.0000e-05
# Epoch 15/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4268 - loss: 1.4722
# Epoch 15: val_accuracy improved from 0.39196 to 0.41709, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.4269 - loss: 1.4722 - val_accuracy: 0.4171 - val_loss: 0.9717 - learning_rate: 2.0000e-05
# Epoch 16/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4155 - loss: 1.5259
# Epoch 16: val_accuracy improved from 0.41709 to 0.43719, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4156 - loss: 1.5253 - val_accuracy: 0.4372 - val_loss: 0.9353 - learning_rate: 2.0000e-05
# Epoch 17/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4205 - loss: 1.5269
# Epoch 17: val_accuracy did not improve from 0.43719
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4209 - loss: 1.5252 - val_accuracy: 0.4372 - val_loss: 0.9310 - learning_rate: 2.0000e-05
# Epoch 18/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4582 - loss: 1.3846
# Epoch 18: val_accuracy improved from 0.43719 to 0.45226, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.4586 - loss: 1.3836 - val_accuracy: 0.4523 - val_loss: 0.9118 - learning_rate: 2.0000e-05
# Epoch 19/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4370 - loss: 1.4545
# Epoch 19: val_accuracy did not improve from 0.45226
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4371 - loss: 1.4536 - val_accuracy: 0.4523 - val_loss: 0.9084 - learning_rate: 2.0000e-05
# Epoch 20/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4878 - loss: 1.3789
# Epoch 20: val_accuracy did not improve from 0.45226
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4873 - loss: 1.3796 - val_accuracy: 0.4472 - val_loss: 0.8975 - learning_rate: 2.0000e-05
# Epoch 21/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4842 - loss: 1.4069
# Epoch 21: val_accuracy did not improve from 0.45226
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.4837 - loss: 1.4071 - val_accuracy: 0.4523 - val_loss: 0.8645 - learning_rate: 2.0000e-05
# Epoch 22/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4282 - loss: 1.4511
# Epoch 22: val_accuracy improved from 0.45226 to 0.45729, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4284 - loss: 1.4495 - val_accuracy: 0.4573 - val_loss: 0.8581 - learning_rate: 2.0000e-05
# Epoch 23/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4696 - loss: 1.3908
# Epoch 23: val_accuracy improved from 0.45729 to 0.46734, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4695 - loss: 1.3905 - val_accuracy: 0.4673 - val_loss: 0.8648 - learning_rate: 2.0000e-05
# Epoch 24/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4753 - loss: 1.2750
# Epoch 24: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4752 - loss: 1.2754 - val_accuracy: 0.4673 - val_loss: 0.8719 - learning_rate: 2.0000e-05
# Epoch 25/75
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.4411 - loss: 1.3992
# Epoch 25: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.4418 - loss: 1.3974 - val_accuracy: 0.4623 - val_loss: 0.8698 - learning_rate: 2.0000e-05
# Epoch 26/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4912 - loss: 1.2872
# Epoch 26: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4908 - loss: 1.2886 - val_accuracy: 0.4623 - val_loss: 0.8675 - learning_rate: 2.0000e-05
# Epoch 27/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4594 - loss: 1.2485
# Epoch 27: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4590 - loss: 1.2510 - val_accuracy: 0.4673 - val_loss: 0.8708 - learning_rate: 2.0000e-05
# Epoch 28/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4658 - loss: 1.3893
# Epoch 28: val_accuracy did not improve from 0.46734
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4652 - loss: 1.3905 - val_accuracy: 0.4673 - val_loss: 0.8700 - learning_rate: 2.0000e-05
# Epoch 29/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4818 - loss: 1.2811
# Epoch 29: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4816 - loss: 1.2820 - val_accuracy: 0.4673 - val_loss: 0.8728 - learning_rate: 4.0000e-06
# Epoch 30/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4872 - loss: 1.3215
# Epoch 30: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.4873 - loss: 1.3211 - val_accuracy: 0.4673 - val_loss: 0.8735 - learning_rate: 4.0000e-06
# Epoch 31/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.4098 - loss: 1.4872
# Epoch 31: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.4106 - loss: 1.4858 - val_accuracy: 0.4623 - val_loss: 0.8788 - learning_rate: 4.0000e-06
# Epoch 32/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.4415 - loss: 1.4535
# Epoch 32: val_accuracy did not improve from 0.46734
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.4416 - loss: 1.4540 - val_accuracy: 0.4673 - val_loss: 0.8754 - learning_rate: 4.0000e-06
# Epoch 33/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.4840 - loss: 1.2923
# Epoch 33: val_accuracy improved from 0.46734 to 0.47236, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4839 - loss: 1.2927 - val_accuracy: 0.4724 - val_loss: 0.8781 - learning_rate: 4.0000e-06
# Epoch 34/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4470 - loss: 1.4375
# Epoch 34: val_accuracy improved from 0.47236 to 0.47739, saving model to /content/drive/MyDrive/ctmodels/best_cnn_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.4472 - loss: 1.4366 - val_accuracy: 0.4774 - val_loss: 0.8800 - learning_rate: 4.0000e-06
# Epoch 35/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4653 - loss: 1.2814
# Epoch 35: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4650 - loss: 1.2825 - val_accuracy: 0.4724 - val_loss: 0.8897 - learning_rate: 4.0000e-06
# Epoch 36/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4898 - loss: 1.2970
# Epoch 36: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.4896 - loss: 1.2976 - val_accuracy: 0.4673 - val_loss: 0.8891 - learning_rate: 4.0000e-06
# Epoch 37/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.4719 - loss: 1.2953
# Epoch 37: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 269ms/step - accuracy: 0.4717 - loss: 1.2965 - val_accuracy: 0.4774 - val_loss: 0.8798 - learning_rate: 4.0000e-06
# Epoch 38/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.4554 - loss: 1.3002
# Epoch 38: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.4550 - loss: 1.3016 - val_accuracy: 0.4774 - val_loss: 0.8829 - learning_rate: 4.0000e-06
# Epoch 39/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4766 - loss: 1.2282
# Epoch 39: val_accuracy did not improve from 0.47739
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4762 - loss: 1.2306 - val_accuracy: 0.4724 - val_loss: 0.8767 - learning_rate: 4.0000e-06
# Epoch 40/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.4672 - loss: 1.2233
# Epoch 40: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.4671 - loss: 1.2253 - val_accuracy: 0.4774 - val_loss: 0.8714 - learning_rate: 1.0000e-06
# Epoch 41/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.4953 - loss: 1.3242
# Epoch 41: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4949 - loss: 1.3240 - val_accuracy: 0.4724 - val_loss: 0.8723 - learning_rate: 1.0000e-06
# Epoch 42/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4707 - loss: 1.4060
# Epoch 42: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.4706 - loss: 1.4060 - val_accuracy: 0.4724 - val_loss: 0.8751 - learning_rate: 1.0000e-06
# Epoch 43/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.4135 - loss: 1.4299
# Epoch 43: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.4143 - loss: 1.4284 - val_accuracy: 0.4673 - val_loss: 0.8751 - learning_rate: 1.0000e-06
# Epoch 44/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.4992 - loss: 1.2832
# Epoch 44: val_accuracy did not improve from 0.47739
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.4991 - loss: 1.2846 - val_accuracy: 0.4774 - val_loss: 0.8708 - learning_rate: 1.0000e-06
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# Loading best weights for Custom CNN...
#
# --- Evaluating Model: Custom_CNN ---
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step
#
# Validation Accuracy: 0.4774
# Cohen's Kappa: 0.3115
# Macro Avg ROC-AUC: 0.8011
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.50      0.03      0.06        67
#    large.cell.carcinoma       0.47      0.41      0.43        37
#                  normal       1.00      1.00      1.00        43
# squamous.cell.carcinoma       0.29      0.67      0.41        52
#
#                accuracy                           0.48       199
#               macro avg       0.57      0.53      0.47       199
#            weighted avg       0.55      0.48      0.42       199

# %%
#  MobileNetV2 (Transfer Learning + Fine-tuning)

print("\n===== Training MobileNetV2 =====")
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# --- Initial Transfer Learning Phase (Base Frozen) ---
print("\n--- Phase 1: Initial Transfer Learning (Base Frozen) ---")
mobilenet_base_model_fn = lambda **kwargs: MobileNetV2(include_top=False, weights='imagenet', input_shape=kwargs.get('input_shape'))

mobilenet_model = build_transfer_model(
    mobilenet_base_model_fn,
    input_shape,
    num_classes,
    trainable_base=False, # Keep base frozen initially
    learning_rate=INITIAL_LR,
    model_name="MobileNetV2_Transfer"
)

# Get callbacks for initial phase
mobilenet_callbacks_initial = get_callbacks(MOBILENET_MODEL_PATH, monitor='val_loss')

# Train the head
print("\nStarting MobileNetV2 Initial Training...")
history_mobilenet_initial = mobilenet_model.fit(
    train_generator,
    epochs=INITIAL_EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=mobilenet_callbacks_initial,
    verbose=1
)

# Plot initial history
plot_training_history(history_mobilenet_initial, title_prefix="MobileNetV2 Initial ")

# --- Fine-tuning Phase (Unfreeze Base) ---
print("\n--- Phase 2: Fine-tuning (Unfreezing Base Model) ---")

# Load the best weights from the initial phase
print("Loading best weights from initial phase...")
mobilenet_model.load_weights(MOBILENET_MODEL_PATH)

# Unfreeze the base model (or parts of it)
mobilenet_model.layers[1].trainable = True # The base model is typically the second layer after Input


# Re-compile the model with a lower learning rate for fine-tuning
mobilenet_model.compile(
    optimizer=Adam(learning_rate=FINETUNE_LR), # Use a very low learning rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
print("Model re-compiled for fine-tuning.")
mobilenet_model.summary() # Show summary with trainable params

# Get callbacks for fine-tuning phase (reuse checkpoint path to potentially overwrite if fine-tuning improves)
mobilenet_callbacks_finetune = get_callbacks(
    MOBILENET_MODEL_PATH,
    monitor='val_loss',
    early_stopping_patience=EARLY_STOPPING_PATIENCE + 5, # Allow a bit more patience for fine-tuning
    reduce_lr_patience=REDUCE_LR_PATIENCE
)

# Continue training (fine-tuning)
print("\nStarting MobileNetV2 Fine-tuning...")
# Determine initial epoch for history continuity if needed (optional)
initial_epoch_finetune = len(history_mobilenet_initial.history['loss'])

history_mobilenet_finetune = mobilenet_model.fit(
    train_generator,
    epochs=initial_epoch_finetune + FINETUNE_EPOCHS, # Total epochs
    initial_epoch=initial_epoch_finetune,        # Start from where initial training stopped
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=mobilenet_callbacks_finetune,
    verbose=1
)


plot_training_history(history_mobilenet_finetune, title_prefix="MobileNetV2 Fine-tuning ")


# Load the absolute best weights (potentially saved during fine-tuning)
print("\nLoading best weights for MobileNetV2 after fine-tuning...")
mobilenet_model.load_weights(MOBILENET_MODEL_PATH) # Best weights overall saved here

# Evaluate the final fine-tuned model
mobilenet_results = evaluate_model(mobilenet_model, validation_generator, classes)
all_model_results['MobileNetV2'] = mobilenet_results
# Out:
# ===== Training MobileNetV2 =====
#
# --- Phase 1: Initial Transfer Learning (Base Frozen) ---
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# MobileNetV2_Transfer Model Built and Compiled (Base Trainable: False).
# Model: "MobileNetV2_Transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,593,092 (9.89 MB)
#  Trainable params: 332,036 (1.27 MB)
#  Non-trainable params: 2,261,056 (8.63 MB)
# Starting MobileNetV2 Initial Training...
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.4386 - loss: 1.5505
# Epoch 1: val_loss improved from inf to 1.10778, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 519ms/step - accuracy: 0.4399 - loss: 1.5464 - val_accuracy: 0.4774 - val_loss: 1.1078 - learning_rate: 0.0010
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.6153 - loss: 1.0046
# Epoch 2: val_loss improved from 1.10778 to 0.78990, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 274ms/step - accuracy: 0.6160 - loss: 1.0032 - val_accuracy: 0.6734 - val_loss: 0.7899 - learning_rate: 0.0010
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.7415 - loss: 0.6746
# Epoch 3: val_loss improved from 0.78990 to 0.58391, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 278ms/step - accuracy: 0.7413 - loss: 0.6745 - val_accuracy: 0.7487 - val_loss: 0.5839 - learning_rate: 0.0010
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.7862 - loss: 0.5611
# Epoch 4: val_loss improved from 0.58391 to 0.51872, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 278ms/step - accuracy: 0.7856 - loss: 0.5625 - val_accuracy: 0.7889 - val_loss: 0.5187 - learning_rate: 0.0010
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.8161 - loss: 0.5126
# Epoch 5: val_loss improved from 0.51872 to 0.45365, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 279ms/step - accuracy: 0.8157 - loss: 0.5131 - val_accuracy: 0.8040 - val_loss: 0.4536 - learning_rate: 0.0010
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7657 - loss: 0.5805
# Epoch 6: val_loss improved from 0.45365 to 0.39790, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 280ms/step - accuracy: 0.7659 - loss: 0.5806 - val_accuracy: 0.8241 - val_loss: 0.3979 - learning_rate: 0.0010
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.7904 - loss: 0.5055
# Epoch 7: val_loss improved from 0.39790 to 0.39341, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 276ms/step - accuracy: 0.7907 - loss: 0.5054 - val_accuracy: 0.8442 - val_loss: 0.3934 - learning_rate: 0.0010
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.7955 - loss: 0.5281
# Epoch 8: val_loss improved from 0.39341 to 0.32558, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 277ms/step - accuracy: 0.7957 - loss: 0.5275 - val_accuracy: 0.8643 - val_loss: 0.3256 - learning_rate: 0.0010
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8483 - loss: 0.4633
# Epoch 9: val_loss improved from 0.32558 to 0.26671, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 277ms/step - accuracy: 0.8478 - loss: 0.4636 - val_accuracy: 0.8995 - val_loss: 0.2667 - learning_rate: 0.0010
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8221 - loss: 0.4226
# Epoch 10: val_loss did not improve from 0.26671
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8222 - loss: 0.4232 - val_accuracy: 0.8844 - val_loss: 0.3044 - learning_rate: 0.0010
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8173 - loss: 0.4944
# Epoch 11: val_loss did not improve from 0.26671
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8175 - loss: 0.4935 - val_accuracy: 0.8693 - val_loss: 0.2742 - learning_rate: 0.0010
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8477 - loss: 0.4158
# Epoch 12: val_loss improved from 0.26671 to 0.26393, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 273ms/step - accuracy: 0.8475 - loss: 0.4161 - val_accuracy: 0.8844 - val_loss: 0.2639 - learning_rate: 0.0010
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8658 - loss: 0.3578
# Epoch 13: val_loss improved from 0.26393 to 0.24887, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 275ms/step - accuracy: 0.8653 - loss: 0.3583 - val_accuracy: 0.8945 - val_loss: 0.2489 - learning_rate: 0.0010
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.8671 - loss: 0.3589
# Epoch 14: val_loss improved from 0.24887 to 0.21925, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 278ms/step - accuracy: 0.8671 - loss: 0.3589 - val_accuracy: 0.9246 - val_loss: 0.2192 - learning_rate: 0.0010
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8507 - loss: 0.4125
# Epoch 15: val_loss did not improve from 0.21925
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8507 - loss: 0.4119 - val_accuracy: 0.9146 - val_loss: 0.2234 - learning_rate: 0.0010
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8788 - loss: 0.3201
# Epoch 16: val_loss improved from 0.21925 to 0.20122, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 276ms/step - accuracy: 0.8783 - loss: 0.3211 - val_accuracy: 0.8995 - val_loss: 0.2012 - learning_rate: 0.0010
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8590 - loss: 0.3878
# Epoch 17: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.8589 - loss: 0.3879 - val_accuracy: 0.9095 - val_loss: 0.2402 - learning_rate: 0.0010
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8897 - loss: 0.2888
# Epoch 18: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.8894 - loss: 0.2892 - val_accuracy: 0.8844 - val_loss: 0.2428 - learning_rate: 0.0010
# Epoch 19/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8902 - loss: 0.2978
# Epoch 19: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.8895 - loss: 0.2992 - val_accuracy: 0.9095 - val_loss: 0.2216 - learning_rate: 0.0010
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9081 - loss: 0.3112
# Epoch 20: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9075 - loss: 0.3120 - val_accuracy: 0.9045 - val_loss: 0.2431 - learning_rate: 0.0010
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8872 - loss: 0.2932
# Epoch 21: val_loss did not improve from 0.20122
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 265ms/step - accuracy: 0.8872 - loss: 0.2935 - val_accuracy: 0.8844 - val_loss: 0.2269 - learning_rate: 0.0010
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8753 - loss: 0.3139
# Epoch 22: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8752 - loss: 0.3143 - val_accuracy: 0.8844 - val_loss: 0.2288 - learning_rate: 2.0000e-04
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8716 - loss: 0.3265
# Epoch 23: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8718 - loss: 0.3261 - val_accuracy: 0.8894 - val_loss: 0.2204 - learning_rate: 2.0000e-04
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.8644 - loss: 0.3085
# Epoch 24: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8649 - loss: 0.3079 - val_accuracy: 0.8945 - val_loss: 0.2075 - learning_rate: 2.0000e-04
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9202 - loss: 0.2609
# Epoch 25: val_loss did not improve from 0.20122
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9199 - loss: 0.2608 - val_accuracy: 0.8894 - val_loss: 0.2123 - learning_rate: 2.0000e-04
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8788 - loss: 0.3241
# Epoch 26: val_loss did not improve from 0.20122
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.8787 - loss: 0.3241 - val_accuracy: 0.9095 - val_loss: 0.2047 - learning_rate: 2.0000e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# --- Phase 2: Fine-tuning (Unfreezing Base Model) ---
# Loading best weights from initial phase...
# Model re-compiled for fine-tuning.
# Model: "MobileNetV2_Transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,593,092 (9.89 MB)
#  Trainable params: 2,555,908 (9.75 MB)
#  Non-trainable params: 37,184 (145.25 KB)
# Starting MobileNetV2 Fine-tuning...
# Epoch 27/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.5173 - loss: 1.6054
# Epoch 27: val_loss improved from inf to 0.37001, saving model to /content/drive/MyDrive/ctmodels/best_mobilenet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 85s 707ms/step - accuracy: 0.5167 - loss: 1.6071 - val_accuracy: 0.8744 - val_loss: 0.3700 - learning_rate: 1.0000e-05
# Epoch 28/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.5376 - loss: 1.4255
# Epoch 28: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 273ms/step - accuracy: 0.5375 - loss: 1.4256 - val_accuracy: 0.7789 - val_loss: 0.5810 - learning_rate: 1.0000e-05
# Epoch 29/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5767 - loss: 1.1281
# Epoch 29: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.5770 - loss: 1.1288 - val_accuracy: 0.6231 - val_loss: 0.9675 - learning_rate: 1.0000e-05
# Epoch 30/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5999 - loss: 1.1644
# Epoch 30: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.6000 - loss: 1.1645 - val_accuracy: 0.6131 - val_loss: 1.1245 - learning_rate: 1.0000e-05
# Epoch 31/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6439 - loss: 1.0649
# Epoch 31: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.6438 - loss: 1.0654 - val_accuracy: 0.6281 - val_loss: 1.1817 - learning_rate: 1.0000e-05
# Epoch 32/56
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.6980 - loss: 0.9346
# Epoch 32: val_loss did not improve from 0.37001
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.6977 - loss: 0.9358 - val_accuracy: 0.6080 - val_loss: 1.3104 - learning_rate: 1.0000e-05
# Epoch 33/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6660 - loss: 0.9582
# Epoch 33: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 269ms/step - accuracy: 0.6659 - loss: 0.9582 - val_accuracy: 0.6281 - val_loss: 1.2778 - learning_rate: 2.0000e-06
# Epoch 34/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.6341 - loss: 1.0171
# Epoch 34: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.6344 - loss: 1.0163 - val_accuracy: 0.6181 - val_loss: 1.2518 - learning_rate: 2.0000e-06
# Epoch 35/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6991 - loss: 0.8973
# Epoch 35: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.6990 - loss: 0.8976 - val_accuracy: 0.6533 - val_loss: 1.1872 - learning_rate: 2.0000e-06
# Epoch 36/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6839 - loss: 0.8747
# Epoch 36: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.6840 - loss: 0.8747 - val_accuracy: 0.6633 - val_loss: 1.1568 - learning_rate: 2.0000e-06
# Epoch 37/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6629 - loss: 0.9318
# Epoch 37: val_loss did not improve from 0.37001
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.6629 - loss: 0.9318 - val_accuracy: 0.6834 - val_loss: 1.1264 - learning_rate: 2.0000e-06
# Epoch 38/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6780 - loss: 0.9286
# Epoch 38: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.6782 - loss: 0.9276 - val_accuracy: 0.7186 - val_loss: 1.0587 - learning_rate: 1.0000e-06
# Epoch 39/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6869 - loss: 0.9618
# Epoch 39: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.6870 - loss: 0.9608 - val_accuracy: 0.7136 - val_loss: 1.0329 - learning_rate: 1.0000e-06
# Epoch 40/56
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.6678 - loss: 0.9148
# Epoch 40: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.6690 - loss: 0.9114 - val_accuracy: 0.7085 - val_loss: 1.0110 - learning_rate: 1.0000e-06
# Epoch 41/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.7043 - loss: 0.7767
# Epoch 41: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.7043 - loss: 0.7778 - val_accuracy: 0.7186 - val_loss: 0.9619 - learning_rate: 1.0000e-06
# Epoch 42/56
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.7260 - loss: 0.7944
# Epoch 42: val_loss did not improve from 0.37001
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.7258 - loss: 0.7949 - val_accuracy: 0.7286 - val_loss: 0.9209 - learning_rate: 1.0000e-06
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 27.
# Loading best weights for MobileNetV2 after fine-tuning...
#
# --- Evaluating Model: MobileNetV2_Transfer ---
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 330ms/step
#
# Validation Accuracy: 0.8744
# Cohen's Kappa: 0.8308
# Macro Avg ROC-AUC: 0.9846
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.96      0.72      0.82        67
#    large.cell.carcinoma       0.94      0.92      0.93        37
#                  normal       1.00      0.93      0.96        43
# squamous.cell.carcinoma       0.71      1.00      0.83        52
#
#                accuracy                           0.87       199
#               macro avg       0.90      0.89      0.89       199
#            weighted avg       0.90      0.87      0.88       199

# %%
# ResNet50 (Transfer Learning + Fine-tuning)


print("\n===== Training ResNet50 =====")
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# --- Initial Transfer Learning Phase (Base Frozen) ---
print("\n--- Phase 1: Initial Transfer Learning (Base Frozen) ---")
resnet_base_model_fn = lambda **kwargs: ResNet50(include_top=False, weights='imagenet', input_shape=kwargs.get('input_shape'))

resnet_model = build_transfer_model(
    resnet_base_model_fn,
    input_shape,
    num_classes,
    trainable_base=False,
    learning_rate=INITIAL_LR,
    model_name="ResNet50_Transfer"
)

# Get callbacks
resnet_callbacks_initial = get_callbacks(RESNET_MODEL_PATH, monitor='val_loss')

# Train the head
print("\nStarting ResNet50 Initial Training...")
history_resnet_initial = resnet_model.fit(
    train_generator,
    epochs=INITIAL_EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=resnet_callbacks_initial,
    verbose=1
)

# Plot initial history
plot_training_history(history_resnet_initial, title_prefix="ResNet50 Initial ")


# --- Fine-tuning Phase (Unfreeze Base) ---
print("\n--- Phase 2: Fine-tuning (Unfreezing Base Model) ---")

# Load the best weights from the initial phase
print("Loading best weights from initial phase...")
resnet_model.load_weights(RESNET_MODEL_PATH)

# Unfreeze the base model
resnet_model.layers[1].trainable = True # Base model



# Re-compile the model with a lower learning rate
resnet_model.compile(
    optimizer=Adam(learning_rate=FINETUNE_LR), # Low LR
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
print("Model re-compiled for fine-tuning.")
resnet_model.summary()

# Get callbacks for fine-tuning phase
resnet_callbacks_finetune = get_callbacks(
    RESNET_MODEL_PATH,
    monitor='val_loss',
    early_stopping_patience=EARLY_STOPPING_PATIENCE + 5,
    reduce_lr_patience=REDUCE_LR_PATIENCE
)

# Continue training (fine-tuning)
print("\nStarting ResNet50 Fine-tuning...")
initial_epoch_finetune_resnet = len(history_resnet_initial.history['loss'])

history_resnet_finetune = resnet_model.fit(
    train_generator,
    epochs=initial_epoch_finetune_resnet + FINETUNE_EPOCHS,
    initial_epoch=initial_epoch_finetune_resnet,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=resnet_callbacks_finetune,
    verbose=1
)

# Plot fine-tuning history
plot_training_history(history_resnet_finetune, title_prefix="ResNet50 Fine-tuning ")

# Load the absolute best weights
print("\nLoading best weights for ResNet50 after fine-tuning...")
resnet_model.load_weights(RESNET_MODEL_PATH)

# Evaluate the final fine-tuned model
resnet_results = evaluate_model(resnet_model, validation_generator, classes)
all_model_results['ResNet50'] = resnet_results
# Out:
# ===== Training ResNet50 =====
#
# --- Phase 1: Initial Transfer Learning (Base Frozen) ---
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ResNet50_Transfer Model Built and Compiled (Base Trainable: False).
# Model: "ResNet50_Transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,122,500 (92.02 MB)
#  Trainable params: 530,180 (2.02 MB)
#  Non-trainable params: 23,592,320 (90.00 MB)
# Starting ResNet50 Initial Training...
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.4364 - loss: 1.6453
# Epoch 1: val_loss improved from inf to 1.73715, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 471ms/step - accuracy: 0.4373 - loss: 1.6407 - val_accuracy: 0.3367 - val_loss: 1.7371 - learning_rate: 0.0010
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5250 - loss: 1.1719
# Epoch 2: val_loss improved from 1.73715 to 1.28720, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 285ms/step - accuracy: 0.5249 - loss: 1.1723 - val_accuracy: 0.3367 - val_loss: 1.2872 - learning_rate: 0.0010
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.4898 - loss: 1.1868
# Epoch 3: val_loss improved from 1.28720 to 1.11769, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.4899 - loss: 1.1860 - val_accuracy: 0.5377 - val_loss: 1.1177 - learning_rate: 0.0010
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.5277 - loss: 1.0975
# Epoch 4: val_loss improved from 1.11769 to 1.05213, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.5281 - loss: 1.0968 - val_accuracy: 0.5226 - val_loss: 1.0521 - learning_rate: 0.0010
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.4871 - loss: 1.1447
# Epoch 5: val_loss improved from 1.05213 to 1.00042, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.4877 - loss: 1.1432 - val_accuracy: 0.6131 - val_loss: 1.0004 - learning_rate: 0.0010
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.4854 - loss: 1.0560
# Epoch 6: val_loss improved from 1.00042 to 0.99658, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 302ms/step - accuracy: 0.4859 - loss: 1.0559 - val_accuracy: 0.5528 - val_loss: 0.9966 - learning_rate: 0.0010
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.5016 - loss: 1.0657
# Epoch 7: val_loss improved from 0.99658 to 0.97563, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.5016 - loss: 1.0656 - val_accuracy: 0.5427 - val_loss: 0.9756 - learning_rate: 0.0010
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.5258 - loss: 0.9600
# Epoch 8: val_loss improved from 0.97563 to 0.94895, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.5261 - loss: 0.9605 - val_accuracy: 0.5427 - val_loss: 0.9489 - learning_rate: 0.0010
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.5531 - loss: 0.9707
# Epoch 9: val_loss improved from 0.94895 to 0.89237, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 306ms/step - accuracy: 0.5533 - loss: 0.9703 - val_accuracy: 0.6231 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.5496 - loss: 1.0184
# Epoch 10: val_loss improved from 0.89237 to 0.86730, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.5497 - loss: 1.0174 - val_accuracy: 0.5477 - val_loss: 0.8673 - learning_rate: 0.0010
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.5504 - loss: 0.9618
# Epoch 11: val_loss improved from 0.86730 to 0.78721, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.5507 - loss: 0.9612 - val_accuracy: 0.6834 - val_loss: 0.7872 - learning_rate: 0.0010
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.5666 - loss: 0.9568
# Epoch 12: val_loss improved from 0.78721 to 0.77479, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.5666 - loss: 0.9570 - val_accuracy: 0.6231 - val_loss: 0.7748 - learning_rate: 0.0010
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.5435 - loss: 1.0016
# Epoch 13: val_loss improved from 0.77479 to 0.73107, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 298ms/step - accuracy: 0.5439 - loss: 1.0010 - val_accuracy: 0.7035 - val_loss: 0.7311 - learning_rate: 0.0010
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.5490 - loss: 1.0258
# Epoch 14: val_loss improved from 0.73107 to 0.72497, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.5490 - loss: 1.0246 - val_accuracy: 0.6985 - val_loss: 0.7250 - learning_rate: 0.0010
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.5540 - loss: 0.9587
# Epoch 15: val_loss did not improve from 0.72497
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 289ms/step - accuracy: 0.5545 - loss: 0.9578 - val_accuracy: 0.6985 - val_loss: 0.7321 - learning_rate: 0.0010
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.5740 - loss: 0.8976
# Epoch 16: val_loss did not improve from 0.72497
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.5739 - loss: 0.8982 - val_accuracy: 0.6734 - val_loss: 0.7575 - learning_rate: 0.0010
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5639 - loss: 0.9369
# Epoch 17: val_loss did not improve from 0.72497
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.5639 - loss: 0.9369 - val_accuracy: 0.6633 - val_loss: 0.7313 - learning_rate: 0.0010
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5722 - loss: 0.9229
# Epoch 18: val_loss did not improve from 0.72497
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.5723 - loss: 0.9227 - val_accuracy: 0.6884 - val_loss: 0.7299 - learning_rate: 0.0010
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5652 - loss: 0.8927
# Epoch 19: val_loss did not improve from 0.72497
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.5649 - loss: 0.8931 - val_accuracy: 0.6985 - val_loss: 0.7425 - learning_rate: 0.0010
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5799 - loss: 0.9365
# Epoch 20: val_loss did not improve from 0.72497
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.5802 - loss: 0.9355 - val_accuracy: 0.6935 - val_loss: 0.7365 - learning_rate: 2.0000e-04
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5829 - loss: 0.8864
# Epoch 21: val_loss did not improve from 0.72497
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.5830 - loss: 0.8866 - val_accuracy: 0.6784 - val_loss: 0.7255 - learning_rate: 2.0000e-04
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5650 - loss: 0.9266
# Epoch 22: val_loss improved from 0.72497 to 0.72465, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 284ms/step - accuracy: 0.5654 - loss: 0.9259 - val_accuracy: 0.6884 - val_loss: 0.7247 - learning_rate: 2.0000e-04
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.5906 - loss: 0.8943
# Epoch 23: val_loss improved from 0.72465 to 0.72321, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 305ms/step - accuracy: 0.5905 - loss: 0.8941 - val_accuracy: 0.6935 - val_loss: 0.7232 - learning_rate: 2.0000e-04
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5828 - loss: 0.8629
# Epoch 24: val_loss improved from 0.72321 to 0.71862, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 310ms/step - accuracy: 0.5827 - loss: 0.8628 - val_accuracy: 0.6884 - val_loss: 0.7186 - learning_rate: 2.0000e-04
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6111 - loss: 0.8654
# Epoch 25: val_loss did not improve from 0.71862
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 280ms/step - accuracy: 0.6109 - loss: 0.8657 - val_accuracy: 0.7186 - val_loss: 0.7186 - learning_rate: 2.0000e-04
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6328 - loss: 0.8509
# Epoch 26: val_loss did not improve from 0.71862
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.6323 - loss: 0.8511 - val_accuracy: 0.7035 - val_loss: 0.7190 - learning_rate: 2.0000e-04
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5841 - loss: 0.8907
# Epoch 27: val_loss did not improve from 0.71862
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.5843 - loss: 0.8907 - val_accuracy: 0.7035 - val_loss: 0.7288 - learning_rate: 2.0000e-04
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6125 - loss: 0.8391
# Epoch 28: val_loss did not improve from 0.71862
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.6123 - loss: 0.8395 - val_accuracy: 0.7085 - val_loss: 0.7235 - learning_rate: 2.0000e-04
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5677 - loss: 0.8522
# Epoch 29: val_loss improved from 0.71862 to 0.70666, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 292ms/step - accuracy: 0.5682 - loss: 0.8522 - val_accuracy: 0.6884 - val_loss: 0.7067 - learning_rate: 2.0000e-04
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6145 - loss: 0.8893
# Epoch 30: val_loss did not improve from 0.70666
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 280ms/step - accuracy: 0.6142 - loss: 0.8894 - val_accuracy: 0.7236 - val_loss: 0.7135 - learning_rate: 2.0000e-04
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5805 - loss: 0.9463
# Epoch 31: val_loss did not improve from 0.70666
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.5809 - loss: 0.9449 - val_accuracy: 0.7337 - val_loss: 0.7153 - learning_rate: 2.0000e-04
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6172 - loss: 0.8647
# Epoch 32: val_loss did not improve from 0.70666
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.6169 - loss: 0.8652 - val_accuracy: 0.6884 - val_loss: 0.7156 - learning_rate: 2.0000e-04
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5862 - loss: 0.8895
# Epoch 33: val_loss did not improve from 0.70666
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.5867 - loss: 0.8891 - val_accuracy: 0.6935 - val_loss: 0.7135 - learning_rate: 2.0000e-04
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5895 - loss: 0.8416
# Epoch 34: val_loss did not improve from 0.70666
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.5894 - loss: 0.8420 - val_accuracy: 0.6834 - val_loss: 0.7107 - learning_rate: 2.0000e-04
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6168 - loss: 0.8315
# Epoch 35: val_loss did not improve from 0.70666
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.6168 - loss: 0.8317 - val_accuracy: 0.6884 - val_loss: 0.7105 - learning_rate: 4.0000e-05
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5784 - loss: 0.8844
# Epoch 36: val_loss did not improve from 0.70666
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.5785 - loss: 0.8841 - val_accuracy: 0.7085 - val_loss: 0.7073 - learning_rate: 4.0000e-05
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5764 - loss: 0.8404
# Epoch 37: val_loss improved from 0.70666 to 0.70591, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 283ms/step - accuracy: 0.5765 - loss: 0.8408 - val_accuracy: 0.6935 - val_loss: 0.7059 - learning_rate: 4.0000e-05
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.5769 - loss: 0.8590
# Epoch 38: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 281ms/step - accuracy: 0.5773 - loss: 0.8587 - val_accuracy: 0.7085 - val_loss: 0.7069 - learning_rate: 4.0000e-05
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6078 - loss: 0.8504
# Epoch 39: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.6076 - loss: 0.8506 - val_accuracy: 0.7136 - val_loss: 0.7083 - learning_rate: 4.0000e-05
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6027 - loss: 0.8534
# Epoch 40: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.6026 - loss: 0.8533 - val_accuracy: 0.7136 - val_loss: 0.7087 - learning_rate: 4.0000e-05
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6137 - loss: 0.8297
# Epoch 41: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.6134 - loss: 0.8301 - val_accuracy: 0.7085 - val_loss: 0.7098 - learning_rate: 4.0000e-05
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6166 - loss: 0.8383
# Epoch 42: val_loss did not improve from 0.70591
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.6165 - loss: 0.8383 - val_accuracy: 0.7136 - val_loss: 0.7089 - learning_rate: 4.0000e-05
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.6046 - loss: 0.8739
# Epoch 43: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.6040 - loss: 0.8739 - val_accuracy: 0.7136 - val_loss: 0.7094 - learning_rate: 8.0000e-06
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6160 - loss: 0.8312
# Epoch 44: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.6161 - loss: 0.8309 - val_accuracy: 0.7186 - val_loss: 0.7099 - learning_rate: 8.0000e-06
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5636 - loss: 0.8980
# Epoch 45: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.5642 - loss: 0.8970 - val_accuracy: 0.7085 - val_loss: 0.7099 - learning_rate: 8.0000e-06
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5775 - loss: 0.8580
# Epoch 46: val_loss did not improve from 0.70591
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.5773 - loss: 0.8585 - val_accuracy: 0.7136 - val_loss: 0.7092 - learning_rate: 8.0000e-06
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.6225 - loss: 0.8524
# Epoch 47: val_loss did not improve from 0.70591
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.6224 - loss: 0.8523 - val_accuracy: 0.7186 - val_loss: 0.7081 - learning_rate: 8.0000e-06
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# --- Phase 2: Fine-tuning (Unfreezing Base Model) ---
# Loading best weights from initial phase...
# Model re-compiled for fine-tuning.
# Model: "ResNet50_Transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,122,500 (92.02 MB)
#  Trainable params: 24,064,772 (91.80 MB)
#  Non-trainable params: 57,728 (225.50 KB)
# Starting ResNet50 Fine-tuning...
# Epoch 48/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.3307 - loss: 2.1760
# Epoch 48: val_loss improved from inf to 2.48659, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 95s 785ms/step - accuracy: 0.3319 - loss: 2.1693 - val_accuracy: 0.2261 - val_loss: 2.4866 - learning_rate: 1.0000e-05
# Epoch 49/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4958 - loss: 1.3264
# Epoch 49: val_loss improved from 2.48659 to 2.38379, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 436ms/step - accuracy: 0.4960 - loss: 1.3265 - val_accuracy: 0.2362 - val_loss: 2.3838 - learning_rate: 1.0000e-05
# Epoch 50/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.5409 - loss: 1.2349
# Epoch 50: val_loss improved from 2.38379 to 1.64727, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - accuracy: 0.5416 - loss: 1.2327 - val_accuracy: 0.3065 - val_loss: 1.6473 - learning_rate: 1.0000e-05
# Epoch 51/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.6366 - loss: 0.8491
# Epoch 51: val_loss improved from 1.64727 to 1.57175, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.6364 - loss: 0.8505 - val_accuracy: 0.3417 - val_loss: 1.5718 - learning_rate: 1.0000e-05
# Epoch 52/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.6528 - loss: 0.7981
# Epoch 52: val_loss improved from 1.57175 to 1.39843, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - accuracy: 0.6527 - loss: 0.7990 - val_accuracy: 0.3920 - val_loss: 1.3984 - learning_rate: 1.0000e-05
# Epoch 53/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.7041 - loss: 0.6803
# Epoch 53: val_loss improved from 1.39843 to 1.12336, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.7040 - loss: 0.6807 - val_accuracy: 0.4422 - val_loss: 1.1234 - learning_rate: 1.0000e-05
# Epoch 54/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.6924 - loss: 0.7049
# Epoch 54: val_loss improved from 1.12336 to 1.02697, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - accuracy: 0.6930 - loss: 0.7040 - val_accuracy: 0.5678 - val_loss: 1.0270 - learning_rate: 1.0000e-05
# Epoch 55/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7737 - loss: 0.5641
# Epoch 55: val_loss improved from 1.02697 to 0.99555, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - accuracy: 0.7733 - loss: 0.5646 - val_accuracy: 0.5578 - val_loss: 0.9955 - learning_rate: 1.0000e-05
# Epoch 56/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.7505 - loss: 0.6533
# Epoch 56: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 376ms/step - accuracy: 0.7507 - loss: 0.6523 - val_accuracy: 0.5226 - val_loss: 1.0250 - learning_rate: 1.0000e-05
# Epoch 57/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8267 - loss: 0.4754
# Epoch 57: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 17s 330ms/step - accuracy: 0.8261 - loss: 0.4761 - val_accuracy: 0.4573 - val_loss: 1.2162 - learning_rate: 1.0000e-05
# Epoch 58/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8070 - loss: 0.4742
# Epoch 58: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.8074 - loss: 0.4737 - val_accuracy: 0.3317 - val_loss: 1.5552 - learning_rate: 1.0000e-05
# Epoch 59/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8285 - loss: 0.4604
# Epoch 59: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.8286 - loss: 0.4600 - val_accuracy: 0.3266 - val_loss: 1.9428 - learning_rate: 1.0000e-05
# Epoch 60/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.8541 - loss: 0.4055
# Epoch 60: val_loss did not improve from 0.99555
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8541 - loss: 0.4053 - val_accuracy: 0.3015 - val_loss: 2.2687 - learning_rate: 1.0000e-05
# Epoch 61/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8638 - loss: 0.3493
# Epoch 61: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8639 - loss: 0.3492 - val_accuracy: 0.3467 - val_loss: 2.2243 - learning_rate: 2.0000e-06
# Epoch 62/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8673 - loss: 0.3256
# Epoch 62: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8676 - loss: 0.3253 - val_accuracy: 0.3819 - val_loss: 1.9435 - learning_rate: 2.0000e-06
# Epoch 63/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8991 - loss: 0.2922
# Epoch 63: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8988 - loss: 0.2929 - val_accuracy: 0.4523 - val_loss: 1.5137 - learning_rate: 2.0000e-06
# Epoch 64/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8549 - loss: 0.3489
# Epoch 64: val_loss did not improve from 0.99555
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.8551 - loss: 0.3489 - val_accuracy: 0.5528 - val_loss: 1.1766 - learning_rate: 2.0000e-06
# Epoch 65/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.8629 - loss: 0.3638
# Epoch 65: val_loss improved from 0.99555 to 0.91477, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8628 - loss: 0.3640 - val_accuracy: 0.6834 - val_loss: 0.9148 - learning_rate: 2.0000e-06
# Epoch 66/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.8889 - loss: 0.3352
# Epoch 66: val_loss improved from 0.91477 to 0.74799, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - accuracy: 0.8888 - loss: 0.3351 - val_accuracy: 0.7236 - val_loss: 0.7480 - learning_rate: 2.0000e-06
# Epoch 67/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8845 - loss: 0.3330
# Epoch 67: val_loss improved from 0.74799 to 0.66648, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.8847 - loss: 0.3326 - val_accuracy: 0.7638 - val_loss: 0.6665 - learning_rate: 2.0000e-06
# Epoch 68/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8796 - loss: 0.2860
# Epoch 68: val_loss improved from 0.66648 to 0.61406, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.8796 - loss: 0.2864 - val_accuracy: 0.7638 - val_loss: 0.6141 - learning_rate: 2.0000e-06
# Epoch 69/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8743 - loss: 0.3613
# Epoch 69: val_loss improved from 0.61406 to 0.56438, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - accuracy: 0.8743 - loss: 0.3608 - val_accuracy: 0.8141 - val_loss: 0.5644 - learning_rate: 2.0000e-06
# Epoch 70/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8862 - loss: 0.3160
# Epoch 70: val_loss improved from 0.56438 to 0.54055, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - accuracy: 0.8861 - loss: 0.3165 - val_accuracy: 0.7940 - val_loss: 0.5406 - learning_rate: 2.0000e-06
# Epoch 71/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8993 - loss: 0.2651
# Epoch 71: val_loss improved from 0.54055 to 0.52789, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.8993 - loss: 0.2650 - val_accuracy: 0.8090 - val_loss: 0.5279 - learning_rate: 2.0000e-06
# Epoch 72/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8828 - loss: 0.2965
# Epoch 72: val_loss improved from 0.52789 to 0.51461, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - accuracy: 0.8829 - loss: 0.2964 - val_accuracy: 0.8191 - val_loss: 0.5146 - learning_rate: 2.0000e-06
# Epoch 73/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9127 - loss: 0.2524
# Epoch 73: val_loss improved from 0.51461 to 0.49263, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 0.9123 - loss: 0.2531 - val_accuracy: 0.8191 - val_loss: 0.4926 - learning_rate: 2.0000e-06
# Epoch 74/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8951 - loss: 0.2871
# Epoch 74: val_loss improved from 0.49263 to 0.46633, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 427ms/step - accuracy: 0.8950 - loss: 0.2872 - val_accuracy: 0.8342 - val_loss: 0.4663 - learning_rate: 2.0000e-06
# Epoch 75/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8929 - loss: 0.3001
# Epoch 75: val_loss improved from 0.46633 to 0.43547, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 309ms/step - accuracy: 0.8928 - loss: 0.3004 - val_accuracy: 0.8291 - val_loss: 0.4355 - learning_rate: 2.0000e-06
# Epoch 76/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8863 - loss: 0.3219
# Epoch 76: val_loss improved from 0.43547 to 0.39547, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 316ms/step - accuracy: 0.8866 - loss: 0.3213 - val_accuracy: 0.8342 - val_loss: 0.3955 - learning_rate: 2.0000e-06
# Epoch 77/77
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9025 - loss: 0.2689
# Epoch 77: val_loss improved from 0.39547 to 0.35949, saving model to /content/drive/MyDrive/ctmodels/best_resnet_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 304ms/step - accuracy: 0.9025 - loss: 0.2692 - val_accuracy: 0.8492 - val_loss: 0.3595 - learning_rate: 2.0000e-06
# Restoring model weights from the end of the best epoch: 77.
# Loading best weights for ResNet50 after fine-tuning...
#
# --- Evaluating Model: ResNet50_Transfer ---
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step
#
# Validation Accuracy: 0.8492
# Cohen's Kappa: 0.7974
# Macro Avg ROC-AUC: 0.9769
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.86      0.73      0.79        67
#    large.cell.carcinoma       0.73      0.89      0.80        37
#                  normal       0.98      1.00      0.99        43
# squamous.cell.carcinoma       0.83      0.85      0.84        52
#
#                accuracy                           0.85       199
#               macro avg       0.85      0.87      0.86       199
#            weighted avg       0.85      0.85      0.85       199

# %%
print("\n===== Model Comparison =====")

# --- Tabular Summary ---
comparison_data = []
for model_name, results in all_model_results.items():
    report = results['classification_report_dict']
    comparison_data.append({
        'Model': model_name,
        'Accuracy': results['accuracy'],
        'Kappa': results['kappa'],
        'ROC-AUC (Macro)': results['roc_auc'],
        'Macro Avg F1': report['macro avg']['f1-score'],
        'Weighted Avg F1': report['weighted avg']['f1-score']
    })

comparison_df = pd.DataFrame(comparison_data)
comparison_df = comparison_df.set_index('Model')
print("\n--- Performance Metrics Summary ---")
print(comparison_df.round(4))

# --- Bar Plots for Key Metrics ---
metrics_to_plot = ['Accuracy', 'Kappa', 'ROC-AUC (Macro)', 'Macro Avg F1']
n_metrics = len(metrics_to_plot)
plt.figure(figsize=(6 * n_metrics, 5))

for i, metric in enumerate(metrics_to_plot):
    plt.subplot(1, n_metrics, i + 1)
    sns.barplot(x=comparison_df.index, y=comparison_df[metric])
    plt.title(metric)
    plt.ylabel(metric)
    plt.xticks(rotation=45, ha='right')
    # Add value labels to bars
    for index, value in enumerate(comparison_df[metric]):
        plt.text(index, value, f'{value:.3f}', ha='center', va='bottom', fontsize=9)


plt.suptitle("Model Performance Comparison", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()


# --- Plot Confusion Matrices Side-by-Side ---
n_models = len(all_model_results)
plt.figure(figsize=(8 * n_models, 7)) # Adjusted figsize
plt.suptitle("Confusion Matrices Comparison", fontsize=16, y=1.0) # Adjusted y position

for i, (model_name, results) in enumerate(all_model_results.items()):
    plt.subplot(1, n_models, i + 1)
    sns.heatmap(results['confusion_matrix'], annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title(f"{model_name}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout
plt.show()

# --- Detailed Classification Reports ---
print("\n--- Detailed Classification Reports ---")
for model_name, results in all_model_results.items():
    print(f"\n--- {model_name} ---")
    print(results['classification_report_str'])
# Out:
# ===== Model Comparison =====
#
# --- Performance Metrics Summary ---
#              Accuracy   Kappa  ROC-AUC (Macro)  Macro Avg F1  Weighted Avg F1
# Model
# CNN            0.4774  0.3115           0.8011        0.4745           0.4222
# MobileNetV2    0.8744  0.8308           0.9846        0.8870           0.8751
# ResNet50       0.8492  0.7974           0.9769        0.8555           0.8483
# --- Detailed Classification Reports ---
#
# --- CNN ---
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.50      0.03      0.06        67
#    large.cell.carcinoma       0.47      0.41      0.43        37
#                  normal       1.00      1.00      1.00        43
# squamous.cell.carcinoma       0.29      0.67      0.41        52
#
#                accuracy                           0.48       199
#               macro avg       0.57      0.53      0.47       199
#            weighted avg       0.55      0.48      0.42       199
#
#
# --- MobileNetV2 ---
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.96      0.72      0.82        67
#    large.cell.carcinoma       0.94      0.92      0.93        37
#                  normal       1.00      0.93      0.96        43
# squamous.cell.carcinoma       0.71      1.00      0.83        52
#
#                accuracy                           0.87       199
#               macro avg       0.90      0.89      0.89       199
#            weighted avg       0.90      0.87      0.88       199
#
#
# --- ResNet50 ---
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.86      0.73      0.79        67
#    large.cell.carcinoma       0.73      0.89      0.80        37
#                  normal       0.98      1.00      0.99        43
# squamous.cell.carcinoma       0.83      0.85      0.84        52
#
#                accuracy                           0.85       199
#               macro avg       0.85      0.87      0.86       199
#            weighted avg       0.85      0.85      0.85       199
